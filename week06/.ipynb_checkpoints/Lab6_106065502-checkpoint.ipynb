# %%
from collections import Counter, defaultdict
from pprint import pprint
import fileinput


akl = dict( [ (x+'-n', True) for x in 'focus, ability, absence, account, achievement, act, action, activity, addition, adoption, adult, advance, advantage, advice, age, aim, alternative, amount, analogy, analysis, application, approach, argument, aspect, assertion, assessment, assistance, association, assumption, attempt, attention, attitude, author, awareness, balance, basis, behaviour, behavior, being, belief, benefit, bias, birth, capacity, case, category, cause, centre, challenge, change, character, characteristic, choice, circumstance, class, classification, code, colleague, combination, commitment, committee, communication, community, comparison, complexity, compromise, concentration, concept, conception, concern, conclusion, condition, conduct, conflict, consensus, consequence, consideration, constraint, construction, content, contradiction, contrast, contribution, control, convention, correlation, country, creation, crisis, criterion, criticism, culture, damage, data, debate, decision, decline, defence, defense, definition, degree, demand, description, destruction, determination, development, difference, difficulty, dilemma, dimension, disadvantage, discovery, discrimination, discussion, distinction, diversity, division, doctrine, effect, effectiveness, element, emphasis, environment, error, essence, establishment, evaluation, event, evidence, evolution, examination, example, exception, exclusion, existence, expansion, experience, experiment, explanation, exposure, extent, extreme, fact, factor, failure, feature, female, figure, finding, force, form, formation, function, future, gain, group, growth, guidance, guideline, hypothesis, idea, identity, impact, implication, importance, improvement, increase, indication, individual, influence, information, insight, instance, institution, integration, interaction, interest, interpretation, intervention, introduction, investigation, isolation, issue, kind, knowledge, lack, learning, level, likelihood, limit, limitation, link, list, literature, logic, loss, maintenance, majority, male, manipulation, mankind, material, means, measure, medium, member, method, minority, mode, model, motivation, movement, need, network, norm, notion, number, observation, observer, occurrence, operation, opportunity, option, organisation, organization, outcome, output, paper, parallel, parent, part, participant, past, pattern, percentage, perception, period, person, personality, perspective, phenomenon, point, policy, population, position, possibility, potential, practice, presence, pressure, problem, procedure, process, production, programme, program, progress, property, proportion, proposition, protection, provision, publication, purpose, quality, question, range, rate, reader, reality, reason, reasoning, recognition, reduction, reference, relation, relationship, relevance, report, representative, reproduction, requirement, research, resistance, resolution, resource, respect, restriction, result, review, rise, risk, role, rule, sample, scale, scheme, scope, search, section, selection, sense, separation, series, service, set, sex, shift, significance, similarity, situation, skill, society, solution, source, space, spread, standard, statistics, stimulus, strategy, stress, structure, subject, success, summary, support, survey, system, target, task, team, technique, tendency, tension, term, theme, theory, tolerance, topic, tradition, transition, trend, type, uncertainty, understanding, unit, use, validity, value, variation, variety, version, view, viewpoint, volume, whole, work, world'.split(', ') ]+\
            [ (x+'-v', True)  for x in 'accept, account, achieve, acquire, act, adapt, adopt, advance, advocate, affect, aid, aim, allocate, allow, alter, analyse, analyze, appear, apply, argue, arise, assert, assess, assign, associate, assist, assume, attain, attempt, attend, attribute, avoid, base, be, become, benefit, can, cause, characterise, characterize, choose, cite, claim, clarify, classify, coincide, combine, compare, compete, comprise, concentrate, concern, conclude, conduct, confine, conform, connect, consider, consist, constitute, construct, contain, contrast, contribute, control, convert, correspond, create, damage, deal, decline, define, demonstrate, depend, derive, describe, design, destroy, determine, develop, differ, differentiate, diminish, direct, discuss, display, distinguish, divide, dominate, effect, eliminate, emerge, emphasize, employ, enable, encounter, encourage, enhance, ensure, establish, evaluate, evolve, examine, exceed, exclude, exemplify, exist, expand, experience, explain, expose, express, extend, facilitate, fail, favour, favor, finance, focus, follow, form, formulate, function, gain, generate, govern, highlight, identify, illustrate, imply, impose, improve, include, incorporate, increase, indicate, induce, influence, initiate, integrate, interpret, introduce, investigate, involve, isolate, label, lack, lead, limit, link, locate, maintain, may, measure, neglect, note, obtain, occur, operate, outline, overcome, participate, perceive, perform, permit, pose, possess, precede, predict, present, preserve, prevent, produce, promote, propose, prove, provide, publish, pursue, quote, receive, record, reduce, refer, reflect, regard, regulate, reinforce, reject, relate, rely, remain, remove, render, replace, report, represent, reproduce, require, resolve, respond, restrict, result, retain, reveal, seek, select, separate, should, show, solve, specify, state, stimulate, strengthen, stress, study, submit, suffer, suggest, summarise, summarize, supply, support, sustain, tackle, tend, term, transform, treat, undermine, undertake, use, vary, view, write, yield'.split(', ') ]+\
            [ (x+'-adj', True) for x in 'absolute, abstract, acceptable, accessible, active, actual, acute, additional, adequate, alternative, apparent, applicable, appropriate, arbitrary, available, average, basic, central, certain, clear, common, competitive, complete, complex, comprehensive, considerable, consistent, conventional, correct, critical, crucial, dependent, detailed, different, difficult, distinct, dominant, early, effective, equal, equivalent, essential, evident, excessive, experimental, explicit, extensive, extreme, far, favourable, favorable, final, fixed, following, formal, frequent, fundamental, future, general, great, high, human, ideal, identical, immediate, important, inadequate, incomplete, independent, indirect, individual, inferior, influential, inherent, initial, interesting, internal, large, late, leading, likely, limited, local, logical, main, major, male, maximum, mental, minimal, minor, misleading, modern, mutual, natural, necessary, negative, new, normal, obvious, original, other, overall, parallel, partial, particular, passive, past, permanent, physical, positive, possible, potential, practical, present, previous, primary, prime, principal, productive, profound, progressive, prominent, psychological, radical, random, rapid, rational, real, realistic, recent, related, relative, relevant, representative, responsible, restricted, scientific, secondary, selective, separate, severe, sexual, significant, similar, simple, single, so-called, social, special, specific, stable, standard, strict, subsequent, substantial, successful, successive, sufficient, suitable, surprising, symbolic, systematic, theoretical, total, traditional, true, typical, unique, unlike, unlikely, unsuccessful, useful, valid, valuable, varied, various, visual, vital, wide, widespread'.split(', ') ]+\
            [ (x+'-adv', True) for x in 'above, accordingly, accurately, adequately, also, approximately, at best, basically, clearly, closely, commonly, consequently, considerably, conversely, correctly, directly, effectively, e.g., either, equally, especially, essentially, explicitly, extremely, fairly, far, for example, for instance, frequently, fully, further, generally, greatly, hence, highly, however, increasingly, indeed, independently, indirectly, inevitably, initially, in general, in particular, largely, less, mainly, more, moreover, most, namely, necessarily, normally, notably, often, only, originally, over, partially, particularly, potentially, previously, primarily, purely, readily, recently, relatively, secondly, significantly, similarly, simply, socially, solely somewhat, specifically, strongly, subsequently, successfully, thereby, therefore, thus, traditionally, typically, ultimately, virtually, wholly, widely'.split(', ') ] )

# %%
def read_ngrams():
    skipBigramDistance = defaultdict(lambda: defaultdict(lambda: Counter()))
#     skipBigramDistance = defaultdict(lambda: defaultdict(lambda: []))

    skipBigramExample = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: Counter())))

#     bigram = open('citeseerx.ngms','r')
    
    for line in fileinput.input():
#     for line in bigram:
        ngram, count = line.split('\t', 1)
        token = ngram.split(' ')
        
        skipBigramDistance[token[0]][token[-1]][len(token)-1] += int(count)
        skipBigramDistance[token[-1]][token[0]][-(len(token)-1)] += int(count)
#         skipBigramDistance[token[-1]][token[0]][-(len(token)-1)].append()

        skipBigramExample[token[0]][token[-1]][len(token)-1][ngram] = int(count)
        skipBigramExample[token[-1]][token[0]][-(len(token)-1)][ngram] = int(count)
        
#         print(line.strip().split(' ')[0])

    return (skipBigramDistance, skipBigramExample)

def grades_sum(my_list): 
    total = 0 
    for grade in my_list:  
        total += grade 
    return total 
    
def grades_average(my_list): 
    sum_of_grades = grades_sum(my_list) 
    average = sum_of_grades / len(my_list) 
    return average 
       
def grades_variance(my_list, average): 
    variance = 0 
    for i in my_list: 
        variance += (average - i) ** 2 
#         variance += (average - my_list[i]) ** 2 
    return variance / len(my_list)

# %%
skipBigramDistance, skipBigramExample = read_ngrams()
# skipBigramExample['focus-n']['paper-n']
# skipBigramDistance['focus-n']['paper-n']
# print(skipBigramDistance)

coll_info = defaultdict(lambda: [])
C1 = []
C2 = []
C3 = defaultdict(lambda: defaultdict())
for i in skipBigramDistance:
    c = {}
    for k in skipBigramDistance[i]:
        c[k] = grades_sum(skipBigramDistance[i][k].values())
    coll_info[i].append(c)
    coll_info[i].append(grades_average(coll_info[i][0].values()))
    coll_info[i].append(grades_variance(list(coll_info[i][0].values()),coll_info[i][1]))

for j in akl.keys():
    try:
        for m in coll_info[j][0]:
#         print(coll_info["focus-n"])
            try:
                if coll_info[j][0][m] - coll_info[j][1]/coll_info[j][2] > 1:
#                 print(coll_info[j][0][m] - coll_info[j][1]/coll_info[j][2] )
                    C1.append([j,m])
            except:
                pass
    except:
        print(j,coll_info[j])
#         if coll_info[j][0][m] - coll_info[j][1]/coll_info[j][2] > 1:
#             C1.append([j,m])
for i,j in C1:
    if coll_info[i][2]>10:
        C2.append([i,j])

for i, j in C2:
    for l in skipBigramDistance[i][j]:
        if skipBigramDistance[i][j][l] > coll_info[i][1]+1*coll_info[i][2]**0.5:
            C3[i][j] = l
# Out:
# should-v []
# at best-adv []
# e.g.-adv []
# for example-adv []
# for instance-adv []
# in general-adv []
# in particular-adv []
# solely somewhat-adv []

# %%
# for i, j in C2:
#     for l in skipBigramDistance[i][j]:
#         print(l)
#         if skipBigramDistance[i][j][l] > coll_info[i][1]+1*coll_info[i][2]**0.5:
#             C3[i][j] = l
print(C3['focus-n']['on-prep'])
# Out:
# 2

# %%
# for i in coll_info:
#     pprint(coll_info[i][0])
# print(C3['focus-n'])
for text in C3.keys():
    print(text)
    for i in C3[text]:
        l = C3[text][i]
#         print(l)
        print(i,skipBigramDistance[text][i][l],\
             sorted(skipBigramExample[text][i][l].items(),key=lambda x: -x[1])[0])
        
#     pre = sorted(list(skipBigramDistance[text].items()),key=lambda x: -sum(x[1].values()))[:18]
#     for i in pre:
#         max_d = sorted(i[1].items(),key=lambda x: -x[1])[:1][0][0]
# #             print(max_d)
#         max_s = sorted(i[1].items(),key=lambda x: -x[1])[:1][0]
#         print(i[0],end=' ')
#         print(max_s,end=' ')
            
#             pprint(sorted(i[1].items(),key=lambda x: -x[1])[:1][0])
#                   sorted(skipBigramExample[text][i[0]][max_d].items(),key=lambda x: -x[1])[0])
#                    sorted(i[1].items(),key=lambda x: -x[1])[:1],\
#         print(sorted(skipBigramExample[text][i[0]][max_d].items(),key=lambda x: -x[1])[0])
    print('\n')
# Out:
# focus-n
# be-v 4151 ('focus-n of-prep this-det paper-n be-v', 1586)
# on-prep 4749 ('focus-n be-v on-prep', 4303)
# with-prep 3181 ('with-prep a-det focus-n', 2223)
# main-adj 2834 ('main-adj focus-n', 2834)
# paper-n 3120 ('focus-n of-prep this-det paper-n', 2162)
# ability-n
# as-prep 914 ('as-prep the-det ability-n', 755)
# be-v 760 ('be-v limit-v in-prep their-pron ability-n', 139)
# by-prep 955 ('by-prep the-det ability-n', 387)
# for-prep 1442 ('for-prep their-pron ability-n', 779)
# have-v 2872 ('have-v the-det ability-n', 2697)
# improve-v 753 ('improve-v the-det ability-n', 407)
# in-prep 2646 ('in-prep their-pron ability-n', 1041)
# on-prep 2729 ('on-prep the-det ability-n', 1804)
# provide-v 886 ('provide-v the-det ability-n', 838)
# require-v 639 ('require-v the-det ability-n', 608)
# use-v 827 ('ability-n to-to use-v', 788)
# with-prep 979 ('ability-n to-to deal-v with-prep', 386)
# cognitive-adj 1137 ('cognitive-adj ability-n', 1137)
# demonstrate-v 1444 ('demonstrate-v the-det ability-n', 1092)
# generalization-n 658 ('generalization-n ability-n', 658)
# learn-v 755 ('ability-n to-to learn-v', 720)
# s-n 1100 ('s-n ability-n', 1100)
# system-n 606 ('system-n be-v the-det ability-n', 200)
# detect-v 1051 ('ability-n to-to detect-v', 1051)
# generate-v 625 ('ability-n to-to generate-v', 625)
# handle-v 676 ('ability-n to-to handle-v', 676)
# identify-v 643 ('ability-n to-to identify-v', 643)
# include-v 771 ('include-v the-det ability-n', 708)
# perform-v 903 ('ability-n to-to perform-v', 903)
# predict-v 800 ('ability-n to-to predict-v', 800)
# produce-v 686 ('ability-n to-to produce-v', 686)
# apo-n 1184 ('apo-n ;-: s-n ability-n', 1084)
# amp-n 989 ('amp-n ;-: apo-n ;-: s-n ability-n', 904)
# we-pron 1155 ('we-pron demonstrate-v the-det ability-n', 243)
# absence-n
# in-prep 13625 ('in-prep the-det absence-n', 13403)
# presence-n 2489 ('presence-n or-c absence-n', 1968)
# even-adv 1236 ('even-adv in-prep the-det absence-n', 1236)
# account-n
# be-v 7661 ('be-v take-v into-prep account-n', 7626)
# into-prep 43664 ('into-prep account-n', 43664)
# take-v 36804 ('take-v into-prep account-n', 36451)
# achievement-n
# academic-adj 618 ('academic-adj achievement-n', 618)
# be-v 408 ('achievement-n be-v', 408)
# in-prep 893 ('achievement-n in-prep', 893)
# on-prep 253 ('on-prep student-n achievement-n', 129)
# student-n 624 ('student-n achievement-n', 624)
# be-v 20845 ('aim-n of-prep this-det paper-n be-v', 6935)
# with-prep 4812 ('with-prep the-det aim-n', 4451)
# paper-n 8324 ('aim-n of-prep this-det paper-n', 7154)
# study-n 6642 ('aim-n of-prep this-det study-n', 5247)
# alternative-n
# as-prep 3086 ('as-prep an-det alternative-n', 3086)
# be-v 1630 ('be-v a-det viable-adj alternative-n', 332)
# for-prep 2750 ('alternative-n for-prep', 2750)
# in-prep 896 ('alternative-n in-prep', 896)
# attractive-adj 920 ('attractive-adj alternative-n', 920)
# design-n 918 ('design-n alternative-n', 918)
# viable-adj 1033 ('viable-adj alternative-n', 1033)
# amount-n
# be-v 1260 ('amount-n of-prep datum-n to-to be-v', 229)
# datum-n 2368 ('amount-n of-prep training-n datum-n', 635)
# in-prep 1637 ('amount-n of-prep datum-n in-prep', 273)
# increase-v 1607 ('increase-v amount-n', 1607)
# on-prep 1614 ('on-prep the-det amount-n', 1510)
# with-prep 1300 ('with-prep a-det small-adj amount-n', 249)
# considerable-adj 1682 ('considerable-adj amount-n', 1682)
# enormous-adj 955 ('enormous-adj amount-n', 955)
# huge-adj 2729 ('huge-adj amount-n', 2729)
# large-adj 12424 ('large-adj amount-n', 12424)
# limit-v 1088 ('limit-v amount-n', 1088)
# reduce-v 2783 ('reduce-v the-det amount-n', 2783)
# same-adj 941 ('same-adj amount-n', 941)
# significant-adj 3133 ('significant-adj amount-n', 3133)
# small-adj 4437 ('small-adj amount-n', 4437)
# substantial-adj 1060 ('substantial-adj amount-n', 1060)
# total-adj 1098 ('total-adj amount-n', 1098)
# vast-adj 1962 ('vast-adj amount-n', 1962)
# energy-n 1020 ('amount-n of-prep energy-n', 1020)
# information-n 4621 ('amount-n of-prep information-n', 4621)
# memory-n 1210 ('amount-n of-prep memory-n', 1210)
# time-n 3516 ('amount-n of-prep time-n', 3516)
# work-n 1218 ('amount-n of-prep work-n', 1218)
# analogy-n
# between-prep 1277 ('analogy-n between-prep', 1277)
# by-prep 940 ('by-prep analogy-n', 940)
# in-prep 1292 ('in-prep analogy-n', 1292)
# with-prep 2127 ('analogy-n with-prep', 2127)
# analysis-n
# base-v 3939 ('base-v on-prep the-det analysis-n', 1633)
# be-v 3576 ('be-v base-v on-prep the-det analysis-n', 466)
# by-prep 2833 ('by-prep the-det analysis-n', 642)
# component-n 9302 ('component-n analysis-n', 9302)
# datum-n 2857 ('analysis-n of-prep the-det datum-n', 1130)
# design-n 2548 ('design-n and-c analysis-n', 2110)
# for-prep 2447 ('for-prep applied-n systems-n analysis-n', 168)
# from-prep 4259 ('from-prep the-det analysis-n', 1962)
# have-v 5222 ('analysis-n have-v', 5222)
# in-prep 13002 ('in-prep the-det analysis-n', 6061)
# indicate-v 3182 ('analysis-n indicate-v', 3182)
# method-n 4720 ('analysis-n method-n', 4720)
# network-n 2746 ('network-n analysis-n', 2746)
# on-prep 4380 ('analysis-n be-v base-v on-prep', 2397)
# perform-v 3690 ('analysis-n be-v perform-v', 3564)
# performance-n 5862 ('performance-n analysis-n', 5862)
# present-v 3094 ('present-v a-det detailed-adj analysis-n', 556)
# program-n 3110 ('program-n analysis-n', 3110)
# result-n 2907 ('result-n of-prep the-det analysis-n', 937)
# reveal-v 5680 ('analysis-n reveal-v', 5680)
# show-v 9430 ('analysis-n show-v', 9430)
# simulation-n 2439 ('analysis-n and-c simulation-n', 1951)
# suggest-v 2724 ('analysis-n suggest-v', 2724)
# technique-n 6106 ('analysis-n technique-n', 6106)
# tool-n 4986 ('analysis-n tool-n', 4986)
# use-v 3038 ('use-v in-prep the-det analysis-n', 659)
# we-pron 3460 ('we-pron present-v a-det detailed-adj analysis-n', 411)
# with-prep 3554 ('analysis-n with-prep', 3554)
# comparative-adj 3072 ('comparative-adj analysis-n', 3072)
# data-n 3076 ('data-n analysis-n', 3076)
# detailed-adj 4760 ('detailed-adj analysis-n', 4760)
# discriminant-adj 2802 ('discriminant-adj analysis-n', 2802)
# empirical-adj 2750 ('empirical-adj analysis-n', 2750)
# factor-n 2600 ('factor-n analysis-n', 2600)
# image-n 5154 ('image-n analysis-n', 5154)
# independent-adj 2545 ('independent-adj component-n analysis-n', 2301)
# numerical-adj 2475 ('numerical-adj analysis-n', 2475)
# pca-n 2451 ('analysis-n (-( pca-n', 2451)
# quantitative-adj 3015 ('quantitative-adj analysis-n', 3015)
# regression-n 4197 ('regression-n analysis-n', 4197)
# sensitivity-n 3459 ('sensitivity-n analysis-n', 3459)
# sequence-n 2480 ('sequence-n analysis-n', 2480)
# spectral-adj 2505 ('spectral-adj analysis-n', 2505)
# static-adj 4199 ('static-adj analysis-n', 4199)
# statistical-adj 7354 ('statistical-adj analysis-n', 7354)
# theoretical-adj 5629 ('theoretical-adj analysis-n', 5629)
# principal-adj 4361 ('principal-adj component-n analysis-n', 4308)
# application-n
# area-n 4380 ('application-n area-n', 4380)
# as-prep 4979 ('application-n ,-, such-adj as-prep', 3529)
# be-v 3347 ('be-v use-v in-prep many-adj application-n', 273)
# by-prep 3637 ('by-prep the-det application-n', 1713)
# distribute-v 5466 ('distribute-v application-n', 5466)
# domain-n 6672 ('application-n domain-n', 6672)
# for-prep 3707 ('for-prep a-det give-v application-n', 359)
# have-v 4143 ('have-v many-adj application-n', 1007)
# in-prep 3982 ('in-prep many-adj practical-adj application-n', 311)
# include-v 3848 ('application-n include-v', 3848)
# on-prep 4106 ('on-prep the-det application-n', 2764)
# other-adj 3856 ('other-adj application-n', 3856)
# range-n 3756 ('range-n of-prep application-n', 3756)
# require-v 3658 ('application-n require-v', 3658)
# several-adj 3456 ('several-adj application-n', 3456)
# such-adj 5696 ('application-n ,-, such-adj', 3617)
# use-v 3497 ('application-n use-v', 3497)
# we-pron 6213 ('we-pron present-v an-det application-n', 680)
# with-prep 4281 ('with-prep the-det application-n', 1171)
# different-adj 3615 ('different-adj application-n', 3615)
# important-adj 3258 ('important-adj application-n', 3258)
# many-adj 5708 ('many-adj practical-adj application-n', 711)
# multimedia-n 5097 ('multimedia-n application-n', 5097)
# new-adj 3824 ('new-adj application-n', 3824)
# parallel-adj 3199 ('parallel-adj application-n', 3199)
# potential-adj 3983 ('potential-adj application-n', 3983)
# practical-adj 6101 ('practical-adj application-n', 6101)
# real-time-adj 3347 ('real-time-adj application-n', 3347)
# various-adj 3309 ('various-adj application-n', 3309)
# web-n 7728 ('web-n application-n', 7728)
# wide-adj 3529 ('wide-adj range-n of-prep application-n', 2377)
# variety-n 3439 ('variety-n of-prep application-n', 3439)
# approach-n
# alternative-adj 4875 ('alternative-adj approach-n', 4875)
# allow-v 4468 ('approach-n allow-v', 4468)
# base-v 10001 ('approach-n be-v base-v', 8786)
# be-v 5077 ('be-v a-det promising-adj approach-n', 956)
# by-prep 5732 ('approach-n by-prep', 5732)
# demonstrate-v 4143 ('demonstrate-v the-det effectiveness-n of-prep our-pron approach-n', 892)
# describe-v 4955 ('describe-v an-det approach-n', 3093)
# different-adj 8403 ('different-adj approach-n', 8403)
# exist-v 5791 ('exist-v approach-n', 5791)
# for-prep 48522 ('approach-n for-prep', 48522)
# have-v 15133 ('approach-n have-v', 15133)
# in-prep 8700 ('in-prep this-det approach-n', 3283)
# not-adv 4489 ('approach-n do-v not-adv', 2208)
# on-prep 12103 ('approach-n be-v base-v on-prep', 8499)
# present-v 11907 ('present-v a-det new-adj approach-n', 4088)
# propose-v 7705 ('propose-v a-det new-adj approach-n', 2764)
# show-v 6384 ('show-v that-prep our-pron approach-n', 3116)
# use-v 4630 ('approach-n can-m be-v use-v', 1407)
# we-pron 19614 ('we-pron present-v a-det new-adj approach-n', 2469)
# with-prep 4061 ('with-prep this-det approach-n', 1316)
# new-adj 24611 ('new-adj approach-n', 24611)
# novel-adj 12860 ('novel-adj approach-n', 12860)
# other-adj 3891 ('other-adj approach-n', 3891)
# previous-adj 5677 ('previous-adj approach-n', 5677)
# problem-n 4704 ('approach-n to-to the-det problem-n', 2374)
# traditional-adj 4030 ('traditional-adj approach-n', 4030)
# paper-n 4289 ('paper-n ,-, we-pron present-v an-det approach-n', 1041)
# argument-n
# against-prep 645 ('argument-n against-prep', 645)
# be-v 1125 ('argument-n can-m be-v', 323)
# for-prep 2905 ('argument-n for-prep', 2905)
# in-prep 1964 ('argument-n in-prep', 1964)
# on-prep 525 ('argument-n base-v on-prep', 406)
# structure-n 545 ('argument-n structure-n', 545)
# theoretical-adj 713 ('theoretical-adj argument-n', 713)
# aspect-n
# as-prep 753 ('aspect-n such-adj as-prep', 710)
# be-v 1274 ('aspect-n of-prep our-pron approach-n be-v', 146)
# in-prep 2987 ('in-prep many-adj aspect-n', 541)
# on-prep 2592 ('on-prep various-adj aspect-n', 340)
# ratio-n 1938 ('aspect-n ratio-n', 1938)
# system-n 1179 ('aspect-n of-prep the-det system-n', 560)
# certain-adj 1066 ('certain-adj aspect-n', 1066)
# different-adj 3583 ('different-adj aspect-n', 3583)
# discuss-v 834 ('discuss-v some-det aspect-n', 311)
# important-adj 5269 ('important-adj aspect-n', 5269)
# information-n 915 ('aspect-n of-prep this-det collection-n of-prep information-n', 915)
# key-adj 2062 ('key-adj aspect-n', 2062)
# be-v 2895 ('be-v an-det attempt-n', 2121)
# have-v 2316 ('attempt-n have-v', 2316)
# in-prep 4754 ('in-prep an-det attempt-n', 4177)
# make-v 2053 ('attempt-n have-v be-v make-v', 1880)
# first-adj 1883 ('first-adj attempt-n', 1883)
# paper-n 1068 ('paper-n be-v an-det attempt-n', 634)
# previous-adj 941 ('previous-adj attempt-n', 941)
# attention-n
# be-v 4849 ('attention-n have-v be-v', 3702)
# from-prep 1829 ('attention-n from-prep', 1829)
# have-v 1824 ('have-v not-adv receive-v much-adj attention-n', 217)
# in-prep 6312 ('attention-n in-prep', 6312)
# increase-v 2201 ('increase-v attention-n', 2201)
# on-prep 2848 ('attention-n on-prep', 2848)
# pay-v 2031 ('attention-n have-v be-v pay-v', 1686)
# attract-v 2740 ('attract-v much-adj attention-n', 906)
# considerable-adj 2600 ('considerable-adj attention-n', 2600)
# little-adj 3238 ('little-adj attention-n', 3238)
# much-adj 4473 ('much-adj attention-n', 4473)
# particular-adj 3593 ('particular-adj attention-n', 3593)
# receive-v 6858 ('receive-v much-adj attention-n', 1660)
# special-adj 3953 ('special-adj attention-n', 3953)
# attitude-n
# be-v 602 ('attitude-n be-v', 602)
# toward-prep 1470 ('attitude-n toward-prep', 1470)
# towards-prep 1730 ('attitude-n towards-prep', 1730)
# positive-adj 415 ('positive-adj attitude-n', 415)
# risk-n 402 ('risk-n attitude-n', 402)
# knowledge-n 389 ('knowledge-n ,-, attitude-n', 267)
# author-n
# be-v 6079 ('be-v available-adj directly-adv from-prep the-det author-n', 2776)
# by-prep 11938 ('by-prep the-det author-n', 8425)
# directly-adv 3546 ('directly-adv from-prep the-det author-n', 3360)
# do-v 6023 ('author-n and-c do-v', 6023)
# for-prep 3021 ('author-n for-prep', 3021)
# from-prep 4918 ('from-prep the-det author-n', 4918)
# have-v 5506 ('author-n have-v', 5506)
# here-adv 5911 ('here-adv be-v those-det of-prep the-det author-n', 5911)
# information-n 2931 ('author-n require-v further-adj information-n', 2027)
# paper-n 3354 ('paper-n be-v those-det of-prep the-det author-n', 2949)
# apo-n 3402 ('author-n &-c amp-n ;-: apo-n', 3136)
# amp-n 3195 ('author-n &-c amp-n', 3195)
# s-n 17158 ('author-n (-( s-n', 17158)
# not-adv 5887 ('author-n (-( s-n )-) and-c not-adv', 5860)
# reflect-v 3769 ('author-n and-c do-v not-adv necessarily-adv reflect-v', 3769)
# necessarily-adv 5675 ('author-n and-c do-v not-adv necessarily-adv', 5020)
# awareness-n
# about-prep 340 ('awareness-n about-prep', 340)
# be-v 595 ('awareness-n be-v', 595)
# in-prep 571 ('awareness-n in-prep', 571)
# grow-v 267 ('grow-v awareness-n', 267)
# increase-v 714 ('increase-v awareness-n', 714)
# public-adj 374 ('public-adj awareness-n', 374)
# raise-v 462 ('raise-v awareness-n', 462)
# situation-n 768 ('situation-n awareness-n', 768)
# situational-adj 721 ('situational-adj awareness-n', 721)
# balance-n
# be-v 834 ('balance-n be-v', 834)
# between-prep 4395 ('balance-n between-prep', 4395)
# energy-n 1181 ('energy-n balance-n', 1181)
# in-prep 799 ('balance-n in-prep', 799)
# load-n 759 ('load-n balance-n', 759)
# sheet-n 1245 ('balance-n sheet-n', 1245)
# good-adj 518 ('good-adj balance-n', 518)
# mass-n 480 ('mass-n balance-n', 480)
# basis-n
# as-prep 8811 ('as-prep a-det basis-n', 4848)
# be-v 5726 ('be-v use-v as-prep a-det basis-n', 868)
# for-prep 25753 ('basis-n for-prep', 25753)
# form-v 3795 ('form-v the-det basis-n', 3327)
# function-n 6389 ('basis-n function-n', 6389)
# on-prep 3580 ('on-prep a-det daily-adj basis-n', 666)
# provide-v 3809 ('provide-v a-det basis-n', 2085)
# use-v 2052 ('use-v as-prep a-det basis-n', 1064)
# radial-adj 2024 ('radial-adj basis-n', 2024)
# behaviour-n
# asymptotic-adj 1504 ('asymptotic-adj behaviour-n', 1504)
# be-v 1377 ('behaviour-n can-m be-v', 518)
# at-prep 466 ('behaviour-n at-prep', 466)
# for-prep 674 ('behaviour-n for-prep', 674)
# in-prep 2964 ('behaviour-n in-prep', 2964)
# on-prep 493 ('on-prep the-det behaviour-n', 450)
# we-pron 533 ('we-pron study-v the-det behaviour-n', 199)
# with-prep 442 ('behaviour-n with-prep', 442)
# critical-adj 460 ('critical-adj behaviour-n', 460)
# dynamic-adj 697 ('dynamic-adj behaviour-n', 697)
# human-adj 533 ('human-adj behaviour-n', 533)
# system-n 756 ('behaviour-n of-prep the-det system-n', 480)
# study-v 481 ('study-v the-det behaviour-n', 455)
# behavior-n
# analyze-v 947 ('analyze-v the-det behavior-n', 808)
# as-prep 1387 ('behavior-n as-prep', 1387)
# asymptotic-adj 3235 ('asymptotic-adj behavior-n', 3235)
# be-v 844 ('behavior-n ,-, which-w be-v', 183)
# at-prep 1406 ('behavior-n at-prep', 1406)
# by-prep 1358 ('behavior-n by-prep', 1358)
# different-adj 853 ('different-adj behavior-n', 853)
# for-prep 2335 ('behavior-n for-prep', 2335)
# from-prep 949 ('behavior-n from-prep', 949)
# have-v 1072 ('behavior-n have-v', 1072)
# in-prep 1262 ('in-prep the-det behavior-n', 573)
# on-prep 1654 ('on-prep the-det behavior-n', 1261)
# such-adj 1013 ('behavior-n of-prep such-adj', 485)
# system-n 2098 ('behavior-n of-prep the-det system-n', 1157)
# we-pron 1542 ('we-pron study-v the-det behavior-n', 532)
# with-prep 1462 ('behavior-n with-prep', 1462)
# dynamic-adj 2220 ('dynamic-adj behavior-n', 2220)
# human-adj 1944 ('human-adj behavior-n', 1944)
# program-n 958 ('program-n behavior-n', 958)
# social-adj 979 ('social-adj behavior-n', 979)
# study-v 1356 ('study-v the-det behavior-n', 1233)
# user-n 1529 ('user-n behavior-n', 1529)
# apo-n 850 ('apo-n ;-: s-n behavior-n', 364)
# being-n
# human-adj 2644 ('human-adj being-n', 2644)
# belief-n
# about-prep 2153 ('belief-n about-prep', 2153)
# bayesian-adj 485 ('bayesian-adj belief-n', 485)
# be-v 904 ('belief-n network-n be-v', 121)
# change-n 702 ('belief-n change-n', 702)
# application-n 1104 ('application-n code-n', 1104)
# be-v 1312 ('code-n ,-, which-w be-v', 334)
# block-n 1523 ('block-n code-n', 1523)
# division-n 1199 ('code-n division-n', 1199)
# for-prep 1251 ('for-prep the-det code-n', 183)
# from-prep 1488 ('code-n from-prep', 1488)
# generate-v 1448 ('generate-v code-n', 1448)
# generation-n 2959 ('code-n generation-n', 2959)
# generator-n 1092 ('code-n generator-n', 1092)
# have-v 1917 ('code-n have-v', 1917)
# in-prep 1769 ('in-prep the-det code-n', 1129)
# line-n 1210 ('line-n of-prep code-n', 1210)
# on-prep 1109 ('code-n on-prep', 1109)
# size-n 1220 ('code-n size-n', 1220)
# use-v 1325 ('code-n use-v', 1325)
# with-prep 2848 ('code-n with-prep', 2848)
# convolutional-adj 1310 ('convolutional-adj code-n', 1310)
# error-n 1118 ('error-n correct-v code-n', 696)
# ldpc-n 1300 ('ldpc-n code-n', 1300)
# linear-adj 1324 ('linear-adj code-n', 1324)
# mobile-adj 1352 ('mobile-adj code-n', 1352)
# source-n 9745 ('source-n code-n', 9745)
# thesaurus-n 3489 ('thesaurus-n code-n', 3489)
# turbo-n 1479 ('turbo-n code-n', 1479)
# your-pron 3489 ('your-pron thesaurus-n code-n', 3489)
# hand-n 3489 ('hand-n later-adv )-) your-pron thesaurus-n code-n', 3489)
# later-adv 3489 ('later-adv )-) your-pron thesaurus-n code-n', 3489)
# colleague-n
# with-prep 2284 ('with-prep colleague-n', 2284)
# my-pron 841 ('my-pron colleague-n', 841)
# share-v 2034 ('share-v with-prep colleague-n', 2034)
# author-n 1654 ('author-n institution-n and-c share-v with-prep colleague-n', 1654)
# institution-n 2029 ('institution-n and-c share-v with-prep colleague-n', 1656)
# combination-n
# as-prep 1360 ('as-prep a-det combination-n', 914)
# be-v 1434 ('be-v base-v on-prep a-det combination-n', 549)
# by-prep 2396 ('by-prep a-det combination-n', 1686)
# base-v 1782 ('base-v on-prep a-det combination-n', 1183)
# for-prep 1078 ('for-prep the-det combination-n', 354)
# in-prep 10098 ('in-prep combination-n', 10098)
# on-prep 2555 ('on-prep a-det combination-n', 1545)
# use-v 5802 ('use-v a-det combination-n', 4342)
# with-prep 1270 ('with-prep a-det combination-n', 711)
# different-adj 1293 ('different-adj combination-n', 1293)
# linear-adj 5491 ('linear-adj combination-n', 5491)
# commitment-n
# as-prep 271 ('as-prep a-det commitment-n', 271)
# be-v 327 ('commitment-n scheme-n be-v', 92)
# bit-n 407 ('bit-n commitment-n', 407)
# by-prep 318 ('commitment-n by-prep', 318)
# in-prep 394 ('commitment-n in-prep', 394)
# protocol-n 239 ('commitment-n protocol-n', 239)
# scheme-n 582 ('commitment-n scheme-n', 582)
# unit-n 256 ('unit-n commitment-n', 256)
# committee-n
# advisory-n 1070 ('advisory-n committee-n', 1070)
# at-prep 635 ('committee-n hearing-n be-v available-adj at-prep', 635)
# be-v 901 ('committee-n hearing-n be-v', 649)
# for-prep 1051 ('committee-n for-prep', 1051)
# hearing-n 680 ('committee-n hearing-n', 680)
# member-n 1815 ('committee-n member-n', 1815)
# online-n 1134 ('online-n community-n', 1134)
# scientific-adj 1828 ('scientific-adj community-n', 1828)
# virtual-adj 1028 ('virtual-adj community-n', 1028)
# request-v 4086 ('community-n ,-, and-c request-v', 4086)
# protocol-n 4465 ('protocol-n for-prep the-det internet-n community-n', 4241)
# track-v 3652 ('track-v protocol-n for-prep the-det internet-n community-n', 3652)
# comparison-n
# be-v 5475 ('comparison-n be-v', 5475)
# by-prep 2150 ('by-prep comparison-n', 2150)
# between-prep 7492 ('comparison-n between-prep', 7492)
# for-prep 3557 ('for-prep comparison-n', 3557)
# in-prep 12523 ('in-prep comparison-n', 12523)
# make-v 2224 ('comparison-n be-v make-v', 2224)
# with-prep 17739 ('comparison-n with-prep', 17739)
# other-adj 2508 ('comparison-n with-prep other-adj', 1738)
# complexity-n
# algorithm-n 1359 ('complexity-n of-prep the-det algorithm-n', 762)
# be-v 2569 ('complexity-n can-m be-v', 557)
# communication-n 2333 ('communication-n complexity-n', 2333)
# class-n 2158 ('complexity-n class-n', 2158)
# due-adj 1142 ('due-adj to-to the-det complexity-n', 917)
# for-prep 1184 ('complexity-n result-n for-prep', 374)
# in-prep 1677 ('in-prep the-det complexity-n', 622)
# increase-v 2138 ('increase-v complexity-n', 2138)
# low-adj 1327 ('low-adj computational-adj complexity-n', 805)
# o-n 1345 ('complexity-n of-prep o-n', 698)
# on-prep 1532 ('on-prep the-det complexity-n', 1307)
# problem-n 1585 ('complexity-n of-prep the-det problem-n', 1027)
# reduce-v 1202 ('reduce-v the-det computational-adj complexity-n', 746)
# result-n 1133 ('complexity-n result-n', 1133)
# theory-n 1880 ('complexity-n theory-n', 1880)
# we-pron 1537 ('we-pron study-v the-det complexity-n', 580)
# with-prep 2042 ('with-prep the-det complexity-n', 745)
# computational-adj 12344 ('computational-adj complexity-n', 12344)
# high-adj 1140 ('high-adj complexity-n', 1140)
# kolmogorov-n 1238 ('kolmogorov-n complexity-n', 1238)
# size-n 1388 ('size-n and-c complexity-n', 1204)
# space-n 1685 ('space-n complexity-n', 1685)
# time-n 5999 ('time-n complexity-n', 5999)
# compromise-n
# between-prep 1316 ('compromise-n between-prep', 1316)
# good-adj 526 ('good-adj compromise-n', 526)
# concentration-n
# at-prep 1879 ('at-prep high-adj concentration-n', 511)
# be-v 747 ('concentration-n have-v be-v', 173)
# high-adj 3393 ('high-adj concentration-n', 3393)
# in-prep 1038 ('in-prep the-det concentration-n', 583)
# low-adj 1831 ('low-adj concentration-n', 1831)
# on-prep 666 ('concentration-n on-prep', 666)
# with-prep 842 ('with-prep high-adj concentration-n', 171)
# different-adj 755 ('different-adj concentration-n', 755)
# concept-n
# as-prep 1525 ('concept-n such-adj as-prep', 1288)
# base-v 3259 ('base-v on-prep the-det concept-n', 2720)
# basic-adj 2867 ('basic-adj concept-n', 2867)
# be-v 1673 ('be-v base-v on-prep the-det concept-n', 1176)
# development-n 5071 ('development-n of-prep policy-n concept-n', 4995)
# for-prep 4775 ('concept-n for-prep', 4775)
# from-prep 2676 ('concept-n from-prep', 2676)
# have-v 1496 ('concept-n have-v', 1496)
# in-prep 1668 ('concept-n use-v in-prep', 305)
# introduce-v 5446 ('introduce-v the-det concept-n', 5008)
# map-n 1256 ('concept-n map-n', 1256)
# on-prep 4313 ('on-prep the-det concept-n', 3691)
# paper-n 1623 ('paper-n introduce-v the-det concept-n', 477)
# such-adj 1309 ('concept-n such-adj', 1309)
# use-v 2584 ('use-v the-det concept-n', 2144)
# we-pron 5965 ('we-pron introduce-v the-det concept-n', 2498)
# fundamental-adj 1283 ('fundamental-adj concept-n', 1283)
# key-adj 1626 ('key-adj concept-n', 1626)
# new-adj 4217 ('new-adj concept-n', 4217)
# policy-n 5018 ('policy-n concept-n', 5018)
# research-n 4995 ('research-n result-n and-c concept-n', 4995)
# result-n 5008 ('result-n and-c concept-n', 5008)
# proof-n 1771 ('proof-n of-prep concept-n', 1771)
# interested-adj 4994 ('concept-n to-to the-det interested-adj', 4994)
# public-n 4994 ('concept-n to-to the-det interested-adj public-n', 4994)
# dissemination-n 4995 ('dissemination-n of-prep research-n result-n and-c concept-n', 4995)
# conception-n
# be-v 141 ('conception-n be-v', 141)
# de-prep 112 ('de-prep conception-n', 112)
# different-adj 98 ('different-adj conception-n', 98)
# la-n 188 ('la-n conception-n', 188)
# concern-n
# be-v 2566 ('be-v a-det major-adj concern-n', 636)
# about-prep 3557 ('concern-n about-prep', 3557)
# for-prep 2975 ('concern-n for-prep', 2975)
# in-prep 3450 ('concern-n in-prep', 3450)
# with-prep 1051 ('concern-n with-prep', 1051)
# main-adj 934 ('main-adj concern-n', 934)
# major-adj 2050 ('major-adj concern-n', 2050)
# privacy-n 1115 ('privacy-n concern-n', 1115)
# security-n 884 ('security-n concern-n', 884)
# separation-n 1124 ('separation-n of-prep concern-n', 1124)
# conclusion-n
# about-prep 1589 ('conclusion-n about-prep', 1589)
# be-v 1657 ('conclusion-n express-v in-prep this-det publication-n be-v', 642)
# express-v 2145 ('conclusion-n express-v', 2145)
# in-prep 2975 ('conclusion-n express-v in-prep', 1648)
# we-pron 1484 ('conclusion-n :-: we-pron', 846)
# result-n 1386 ('conclusion-n :-: our-pron result-n', 452)
# condition-n
# at-prep 2037 ('condition-n at-prep', 2037)
# be-v 2169 ('condition-n ,-, it-pron be-v', 339)
# boundary-adj 17523 ('boundary-adj condition-n', 17523)
# certain-adj 4047 ('certain-adj condition-n', 4047)
# for-prep 27557 ('condition-n for-prep', 27557)
# in-prep 3210 ('in-prep the-det condition-n', 272)
# necessary-adj 6535 ('necessary-adj and-c sufficient-adj condition-n', 6383)
# number-n 2041 ('condition-n number-n', 2041)
# on-prep 10506 ('condition-n on-prep', 10506)
# sufficient-adj 14632 ('sufficient-adj condition-n', 14632)
# under-prep 3290 ('under-prep the-det same-adj condition-n', 420)
# we-pron 2755 ('we-pron give-v sufficient-adj condition-n', 414)
# environmental-adj 2892 ('environmental-adj condition-n', 2892)
# experimental-adj 2044 ('experimental-adj condition-n', 2044)
# initial-adj 6819 ('initial-adj condition-n', 6819)
# network-n 2106 ('network-n condition-n', 2106)
# operating-n 2209 ('operating-n condition-n', 2209)
# conduct-n
# in-prep 268 ('in-prep the-det united-n state-n ;-: conduct-n', 268)
# publish-v 269 ('conduct-n and-c publish-v', 269)
# monetary-adj 305 ('conduct-n of-prep monetary-adj', 305)
# state-n 268 ('state-n ;-: conduct-n', 268)
# ...
# detailed-adj 4279 ('more-adv detailed-adj', 4279)
# difficult-adj 6348 ('more-adv difficult-adj', 6348)
# effective-adj 8331 ('more-adv effective-adj', 8331)
# efficient-adj 14867 ('more-adv efficient-adj', 14867)
# efficiently-adv 3436 ('more-adv efficiently-adv', 3436)
# flexible-adj 3912 ('more-adv flexible-adj', 3912)
# important-adj 7567 ('more-adv important-adj', 7567)
# importantly-adv 3983 ('more-adv importantly-adv', 3983)
# likely-adj 11038 ('more-adv likely-adj', 11038)
# powerful-adj 4000 ('more-adv powerful-adj', 4000)
# precise-adj 3625 ('more-adv precise-adj', 3625)
# precisely-adv 7742 ('more-adv precisely-adv', 7742)
# realistic-adj 4245 ('more-adv realistic-adj', 4245)
# recent-adj 3618 ('more-adv recent-adj', 3618)
# recently-adv 5178 ('more-adv recently-adv', 5178)
# robust-adj 5344 ('more-adv robust-adj', 5344)
# significantly-adv 3817 ('significantly-adv more-adv', 3817)
# sophisticated-adj 3858 ('more-adv sophisticated-adj', 3858)
# specifically-adv 6888 ('more-adv specifically-adv', 6888)
# than-prep 33152 ('more-adv efficient-adj than-prep', 3408)
# we-pron 6071 ('more-adv precisely-adv ,-, we-pron', 2326)
# with-prep 4001 ('with-prep more-adv', 4001)
# much-adv 12525 ('much-adv more-adv', 12525)
# more-adv 5450 ('more-adv and-c more-adv', 5450)
# moreover-adv
# be-v 2736 ('moreover-adv ,-, it-pron be-v', 1692)
# in-prep 1703 ('moreover-adv ,-, in-prep', 1703)
# it-pron 3860 ('moreover-adv ,-, it-pron', 3860)
# show-v 2480 ('moreover-adv ,-, we-pron show-v', 2360)
# we-pron 11884 ('moreover-adv ,-, we-pron', 11884)
# most-adv
# as-prep 2630 ('as-prep the-det most-adv', 2494)
# be-v 15387 ('be-v one-c of-prep the-det most-adv', 13300)
# in-prep 3810 ('most-adv important-adj problem-n in-prep', 305)
# appropriate-adj 3272 ('most-adv appropriate-adj', 3272)
# common-adj 11106 ('most-adv common-adj', 11106)
# commonly-adv 4200 ('most-adv commonly-adv', 4200)
# effective-adj 3976 ('most-adv effective-adj', 3976)
# efficient-adj 3308 ('most-adv efficient-adj', 3308)
# frequently-adv 2708 ('most-adv frequently-adv', 2708)
# general-adj 3596 ('most-adv general-adj', 3596)
# important-adj 23412 ('most-adv important-adj', 23412)
# importantly-adv 2675 ('most-adv importantly-adv', 2675)
# likely-adj 5227 ('most-adv likely-adj', 5227)
# likely-adv 2666 ('most-adv likely-adv', 2666)
# often-adv 2490 ('most-adv often-adv', 2490)
# popular-adj 5292 ('most-adv popular-adj', 5292)
# promising-adj 3281 ('most-adv promising-adj', 3281)
# recent-adj 7622 ('most-adv recent-adj', 7622)
# relevant-adj 3023 ('most-adv relevant-adj', 3023)
# significant-adj 3657 ('most-adv significant-adj', 3657)
# use-v 5769 ('most-adv widely-adv use-v', 2548)
# widely-adv 3701 ('most-adv widely-adv', 3701)
# among-prep 3037 ('among-prep the-det most-adv', 3037)
# namely-adv
# algorithm-n 644 ('algorithm-n ,-, namely-adv', 623)
# approach-n 415 ('approach-n ,-, namely-adv', 415)
# be-v 582 ('be-v consider-v ,-, namely-adv', 118)
# method-n 523 ('method-n ,-, namely-adv', 523)
# model-n 676 ('model-n ,-, namely-adv', 649)
# application-n 341 ('application-n ,-, namely-adv', 341)
# in-prep 293 ('namely-adv in-prep', 293)
# it-pron 295 ('namely-adv ,-, it-pron', 231)
# system-n 885 ('system-n ,-, namely-adv', 836)
# we-pron 1061 ('namely-adv ,-, we-pron', 1061)
# parameter-n 287 ('parameter-n ,-, namely-adv', 287)
# problem-n 934 ('problem-n ,-, namely-adv', 885)
# technique-n 514 ('technique-n ,-, namely-adv', 514)
# show-v 272 ('namely-adv ,-, we-pron show-v', 272)
# network-n 249 ('network-n ,-, namely-adv', 249)
# property-n 266 ('property-n ,-, namely-adv', 246)
# scheme-n 251 ('scheme-n ,-, namely-adv', 251)
# structure-n 235 ('structure-n ,-, namely-adv', 235)
# theory-n 247 ('theory-n ,-, namely-adv', 247)
# necessarily-adv
# be-v 5477 ('be-v not-adv necessarily-adv', 5477)
# do-v 20433 ('do-v not-adv necessarily-adv', 20318)
# reflect-v 9279 ('necessarily-adv reflect-v', 9279)
# represent-v 4297 ('necessarily-adv represent-v', 4297)
# not-adv 33911 ('not-adv necessarily-adv', 33911)
# view-n 6359 ('necessarily-adv reflect-v the-det view-n', 4368)
# author-n 5675 ('author-n and-c do-v not-adv necessarily-adv', 5020)
# normally-adv
# be-v 3260 ('be-v normally-adv', 3260)
# in-prep 559 ('normally-adv use-v in-prep', 113)
# distribute-v 878 ('normally-adv distribute-v', 878)
# not-adv 537 ('not-adv normally-adv', 537)
# notably-adv
# most-adv 2301 ('most-adv notably-adv', 2301)
# in-prep 562 ('notably-adv in-prep', 562)
# often-adv
# as-prep 3599 ('often-adv use-v as-prep', 614)
# be-v 5073 ('often-adv represent-v preliminary-adj work-n and-c be-v', 4998)
# discussion-n 4940 ('discussion-n papers-n often-adv', 4940)
# have-v 3233 ('often-adv have-v', 3233)
# in-prep 7172 ('often-adv use-v in-prep', 1231)
# it-pron 5995 ('it-pron be-v often-adv', 5644)
# more-adv 2539 ('more-adv often-adv', 2539)
# most-adv 2490 ('most-adv often-adv', 2490)
# by-prep 3275 ('often-adv limit-v by-prep', 249)
# represent-v 5562 ('often-adv represent-v', 5562)
# require-v 3328 ('often-adv require-v', 3328)
# use-v 6986 ('often-adv use-v', 6986)
# papers-n 4960 ('papers-n often-adv', 4960)
# work-n 5004 ('often-adv represent-v preliminary-adj work-n', 5004)
# preliminary-adj 5137 ('often-adv represent-v preliminary-adj', 5137)
# iza-n 4928 ('iza-n discussion-n papers-n often-adv', 4928)
# only-adv
# at-prep 3470 ('only-adv at-prep', 3470)
# be-v 5002 ('only-adv if-prep it-pron be-v', 1316)
# by-prep 5689 ('only-adv by-prep', 5689)
# depend-v 4430 ('depend-v only-adv', 4430)
# for-prep 3145 ('for-prep personal-adj use-n only-adv', 969)
# have-v 7566 ('have-v only-adv', 7566)
# if-prep 13167 ('if-prep and-c only-adv', 12969)
# in-prep 14239 ('only-adv in-prep', 14239)
# it-pron 3254 ('only-adv if-prep it-pron', 2364)
# not-adv 56597 ('not-adv only-adv', 56597)
# on-prep 11692 ('only-adv on-prep', 11692)
# few-adj 6187 ('only-adv a-det few-adj', 5934)
# require-v 4591 ('require-v only-adv', 4591)
# small-adj 5558 ('only-adv a-det small-adj', 5163)
# use-v 12194 ('use-v only-adv', 12194)
# with-prep 7141 ('with-prep only-adv', 7141)
# originally-adv
# article-n 5505 ('article-n originally-adv', 5505)
# be-v 3148 ('originally-adv publish-v in-prep circulation-n can-m be-v', 1444)
# develop-v 1861 ('originally-adv develop-v', 1861)
# by-prep 2047 ('originally-adv propose-v by-prep', 556)
# for-prep 2157 ('originally-adv develop-v for-prep', 887)
# in-prep 7196 ('originally-adv publish-v in-prep', 6083)
# publish-v 6249 ('originally-adv publish-v', 6249)
# circulation-n 2761 ('originally-adv publish-v in-prep circulation-n', 2761)
# portion-n 5486 ('portion-n of-prep article-n originally-adv', 5486)
# over-adv
# be-v 631 ('be-v take-v over-adv', 338)
# carry-v 1155 ('carry-v over-adv', 1155)
# take-v 1216 ('take-v over-adv', 1216)
# partially-adv
# be-v 1054 ('be-v only-adv partially-adv', 732)
# by-prep 3438 ('partially-adv support-v by-prep', 2391)
# least-adj 735 ('least-adj partially-adv', 735)
# only-adv 1491 ('only-adv partially-adv', 1491)
# observable-adj 1338 ('partially-adv observable-adj', 1338)
# order-v 2041 ('partially-adv order-v', 2041)
# support-v 2532 ('partially-adv support-v', 2532)
# at-prep 733 ('at-prep least-adj partially-adv', 733)
# markov-n 705 ('partially-adv observable-adj markov-n', 644)
# set-n 950 ('partially-adv order-v set-n', 950)
# particularly-adv
# be-v 18983 ('be-v particularly-adv', 18983)
# for-prep 5108 ('particularly-adv suitable-adj for-prep', 919)
# in-prep 3971 ('particularly-adv interested-adj in-prep', 698)
# important-adj 2423 ('particularly-adv important-adj', 2423)
# useful-adj 2269 ('particularly-adv useful-adj', 2269)
# potentially-adv
# be-v 646 ('be-v a-det potentially-adv', 531)
# important-adj 711 ('potentially-adv important-adj', 711)
# large-adj 819 ('potentially-adv large-adj', 819)
# lead-v 481 ('potentially-adv lead-v', 481)
# useful-adj 1289 ('potentially-adv useful-adj', 1289)
# with-prep 720 ('with-prep potentially-adv', 720)
# previously-adv
# be-v 2503 ('be-v not-adv previously-adv', 284)
# describe-v 1979 ('previously-adv describe-v', 1979)
# develop-v 1925 ('previously-adv develop-v', 1925)
# have-v 1917 ('have-v not-adv be-v previously-adv', 722)
# in-prep 2743 ('previously-adv report-v in-prep', 305)
# know-v 4954 ('previously-adv know-v', 4954)
# not-adv 1868 ('not-adv previously-adv', 1868)
# propose-v 4640 ('previously-adv propose-v', 4640)
# publish-v 3731 ('previously-adv publish-v', 3731)
# report-v 4568 ('previously-adv report-v', 4568)
# show-v 2091 ('previously-adv show-v', 2091)
# unknown-adj 1589 ('previously-adv unknown-adj', 1589)
# we-pron 2917 ('we-pron have-v previously-adv', 2638)
# than-prep 3062 ('than-prep previously-adv', 3062)
# primarily-adv
# be-v 2442 ('be-v base-v primarily-adv', 252)
# focus-v 1139 ('focus-v primarily-adv', 1139)
# by-prep 1502 ('primarily-adv by-prep', 1502)
# in-prep 1629 ('primarily-adv in-prep', 1629)
# on-prep 1297 ('primarily-adv focus-v on-prep', 684)
# purely-adv
# be-v 482 ('be-v a-det purely-adv', 298)
# from-prep 364 ('from-prep a-det purely-adv', 297)
# in-prep 688 ('in-prep a-det purely-adv', 559)
# on-prep 375 ('purely-adv on-prep', 375)
# algebraic-adj 483 ('purely-adv algebraic-adj', 483)
# combinatorial-adj 411 ('purely-adv combinatorial-adj', 411)
# functional-adj 581 ('purely-adv functional-adj', 581)
# readily-adv
# be-v 1021 ('be-v not-adv readily-adv', 644)
# not-adv 1044 ('not-adv readily-adv', 1044)
# available-adj 2423 ('readily-adv available-adj', 2423)
# recently-adv
# be-v 4255 ('be-v a-det recently-adv', 873)
# by-prep 4088 ('recently-adv propose-v by-prep', 996)
# develop-v 5557 ('recently-adv develop-v', 5557)
# have-v 3400 ('recently-adv ,-, there-e have-v', 1310)
# introduce-v 4006 ('recently-adv introduce-v', 4006)
# more-adv 5178 ('more-adv recently-adv', 5178)
# propose-v 9237 ('recently-adv propose-v', 9237)
# relatively-adv
# be-v 2972 ('be-v a-det relatively-adv', 2214)
# few-adj 1602 ('relatively-adv few-adj', 1602)
# have-v 1767 ('have-v a-det relatively-adv', 687)
# easy-adj 1248 ('relatively-adv easy-adj', 1248)
# high-adj 3343 ('relatively-adv high-adj', 3343)
# large-adj 2536 ('relatively-adv large-adj', 2536)
# little-adj 2398 ('relatively-adv little-adj', 2398)
# low-adj 3750 ('relatively-adv low-adj', 3750)
# new-adj 2024 ('relatively-adv new-adj', 2024)
# short-adj 1142 ('relatively-adv short-adj', 1142)
# simple-adj 3113 ('relatively-adv simple-adj', 3113)
# small-adj 5493 ('relatively-adv small-adj', 5493)
# with-prep 2292 ('with-prep relatively-adv', 2292)
# number-n 1187 ('relatively-adv small-adj number-n', 878)
# secondly-adv
# it-pron 515 ('secondly-adv ,-, it-pron', 515)
# we-pron 2124 ('secondly-adv ,-, we-pron', 2124)
# significantly-adv
# affect-v 2725 ('significantly-adv affect-v', 2725)
# be-v 4829 ('be-v not-adv significantly-adv', 2036)
# by-prep 2411 ('significantly-adv affect-v by-prep', 556)
# differ-v 2467 ('differ-v significantly-adv', 2467)
# have-v 2215 ('have-v a-det significantly-adv', 770)
# improve-v 9815 ('significantly-adv improve-v', 9815)
# in-prep 5248 ('significantly-adv high-adj in-prep', 1450)
# increase-v 5952 ('significantly-adv increase-v', 5952)
# more-adv 3817 ('significantly-adv more-adv', 3817)
# not-adv 3863 ('not-adv significantly-adv', 3863)
# outperform-v 2825 ('significantly-adv outperform-v', 2825)
# reduce-v 10520 ('significantly-adv reduce-v', 10520)
# different-adj 3877 ('significantly-adv different-adj', 3877)
# good-adj 3990 ('significantly-adv good-adj', 3990)
# high-adj 7332 ('significantly-adv high-adj', 7332)
# low-adj 3959 ('significantly-adv low-adj', 3959)
# than-prep 8314 ('significantly-adv good-adj than-prep', 1805)
# with-prep 2768 ('significantly-adv associate-v with-prep', 1519)
# similarly-adv
# be-v 1139 ('be-v similarly-adv', 1139)
# in-prep 336 ('similarly-adv ,-, in-prep', 287)
# we-pron 366 ('similarly-adv ,-, we-pron', 366)
# simply-adv
# be-v 1380 ('be-v not-adv simply-adv', 688)
# by-prep 1288 ('simply-adv by-prep', 1288)
# connect-v 2170 ('simply-adv connect-v', 2170)
# not-adv 1536 ('not-adv simply-adv', 1536)
# type-v 680 ('simply-adv type-v', 680)
# than-prep 822 ('than-prep simply-adv', 822)
# socially-adv
# be-v 511 ('be-v socially-adv', 511)
# optimal-adj 467 ('socially-adv optimal-adj', 467)
# responsible-adj 184 ('socially-adv responsible-adj', 184)
# specifically-adv
# be-v 3901 ('be-v specifically-adv', 3901)
# design-v 2509 ('specifically-adv design-v', 2509)
# for-prep 2285 ('specifically-adv design-v for-prep', 1164)
# more-adv 6888 ('more-adv specifically-adv', 6888)
# show-v 1408 ('specifically-adv ,-, we-pron show-v', 1408)
# we-pron 12510 ('specifically-adv ,-, we-pron', 12510)
# strongly-adv
# affect-v 1287 ('strongly-adv affect-v', 1287)
# be-v 1686 ('be-v more-adv strongly-adv', 398)
# by-prep 2479 ('strongly-adv influence-v by-prep', 949)
# correlate-v 1794 ('strongly-adv correlate-v', 1794)
# couple-v 1417 ('strongly-adv couple-v', 1417)
# depend-v 1277 ('strongly-adv depend-v', 1277)
# influence-v 1672 ('strongly-adv influence-v', 1672)
# interact-v 1132 ('strongly-adv interact-v', 1132)
# more-adv 1296 ('more-adv strongly-adv', 1296)
# on-prep 2199 ('strongly-adv depend-v on-prep', 1231)
# suggest-v 2085 ('strongly-adv suggest-v', 2085)
# support-v 1119 ('strongly-adv support-v', 1119)
# with-prep 1801 ('strongly-adv associate-v with-prep', 842)
# subsequently-adv
# be-v 641 ('subsequently-adv be-v', 641)
# use-v 700 ('subsequently-adv use-v', 700)
# we-pron 747 ('subsequently-adv ,-, we-pron', 747)
# successfully-adv
# apply-v 4515 ('successfully-adv apply-v', 4515)
# be-v 2777 ('be-v use-v successfully-adv', 1213)
# have-v 1658 ('have-v be-v use-v successfully-adv', 843)
# in-prep 2262 ('successfully-adv use-v in-prep', 831)
# use-v 2974 ('successfully-adv use-v', 2974)
# thereby-adv
# be-v 556 ('be-v thereby-adv', 556)
# system-n 240 ('system-n ,-, thereby-adv', 186)
# allow-v 898 ('thereby-adv allow-v', 898)
# avoid-v 427 ('thereby-adv avoid-v', 427)
# create-v 257 ('thereby-adv create-v', 257)
# eliminate-v 234 ('thereby-adv eliminate-v', 234)
# enable-v 608 ('thereby-adv enable-v', 608)
# enhance-v 279 ('thereby-adv enhance-v', 279)
# extend-v 248 ('thereby-adv extend-v', 248)
# facilitate-v 292 ('thereby-adv facilitate-v', 292)
# improve-v 753 ('thereby-adv improve-v', 753)
# increase-v 793 ('thereby-adv increase-v', 793)
# make-v 614 ('thereby-adv make-v', 614)
# obtain-v 246 ('thereby-adv obtain-v', 246)
# provide-v 1175 ('thereby-adv provide-v', 1175)
# reduce-v 1258 ('thereby-adv reduce-v', 1258)
# we-pron 279 ('we-pron thereby-adv', 279)
# therefore-adv
# be-v 4637 ('therefore-adv ,-, it-pron be-v', 2495)
# it-pron 3646 ('therefore-adv ,-, it-pron', 3619)
# in-prep 1879 ('therefore-adv ,-, in-prep', 1726)
# we-pron 5623 ('therefore-adv ,-, we-pron', 5623)
# thus-adv
# allow-v 2518 ('thus-adv allow-v', 2518)
# be-v 3799 ('thus-adv ,-, it-pron be-v', 1711)
# have-v 1089 ('thus-adv have-v', 1089)
# it-pron 3553 ('thus-adv ,-, it-pron', 2947)
# make-v 1860 ('thus-adv make-v', 1860)
# obtain-v 1397 ('thus-adv obtain-v', 1397)
# provide-v 3944 ('thus-adv provide-v', 3944)
# enable-v 1320 ('thus-adv enable-v', 1320)
# far-adv 2566 ('thus-adv far-adv', 2566)
# for-prep 1511 ('thus-adv ,-, for-prep', 776)
# in-prep 2438 ('thus-adv ,-, in-prep', 1835)
# not-adv 1108 ('thus-adv do-v not-adv', 420)
# reduce-v 1663 ('thus-adv reduce-v', 1663)
# we-pron 4006 ('thus-adv ,-, we-pron', 3985)
# traditionally-adv
# be-v 2183 ('traditionally-adv be-v', 2183)
# have-v 3304 ('have-v traditionally-adv', 3304)
# use-v 1066 ('traditionally-adv use-v', 1066)
# typically-adv
# be-v 1358 ('typically-adv be-v', 1358)
# by-prep 1025 ('typically-adv characterize-v by-prep', 141)
# have-v 1551 ('typically-adv have-v', 1551)
# in-prep 2606 ('typically-adv use-v in-prep', 468)
# on-prep 1350 ('typically-adv base-v on-prep', 421)
# require-v 1250 ('typically-adv require-v', 1250)
# use-v 2349 ('typically-adv use-v', 2349)
# ultimately-adv
# be-v 351 ('ultimately-adv be-v', 351)
# lead-v 545 ('ultimately-adv lead-v', 545)
# virtually-adv
# be-v 1780 ('be-v virtually-adv', 1780)
# in-prep 628 ('in-prep virtually-adv', 628)
# wholly-adv
# be-v 250 ('be-v wholly-adv', 250)
# widely-adv
# as-prep 2805 ('widely-adv use-v as-prep', 924)
# be-v 5708 ('be-v a-det widely-adv', 1997)
# for-prep 2743 ('widely-adv use-v for-prep', 2271)
# have-v 7297 ('have-v be-v widely-adv', 6958)
# in-prep 9062 ('widely-adv use-v in-prep', 6319)
# most-adv 3701 ('most-adv widely-adv', 3701)
# use-v 23156 ('widely-adv use-v', 23156)
# accept-v 3291 ('widely-adv accept-v', 3291)

# %%
# if __name__ == '__main__':

#     skipBigramDistance, skipBigramExample = read_ngrams()
#     for text in C3.keys():
#         print(text,'\t','18')
#         pre = sorted(list(skipBigramDistance[text].items()),key=lambda x: -sum(x[1].values()))[:18]
#         for i in pre:
#             max_d = sorted(i[1].items(),key=lambda x: -x[1])[:1][0][0]
# #             print(max_d)
#             max_s = sorted(i[1].items(),key=lambda x: -x[1])[:1][0]
#             print(i[0],end=' ')
#             print(max_s,end=' ')
            
# #             pprint(sorted(i[1].items(),key=lambda x: -x[1])[:1][0])
# #                   sorted(skipBigramExample[text][i[0]][max_d].items(),key=lambda x: -x[1])[0])
# #                    sorted(i[1].items(),key=lambda x: -x[1])[:1],\
#             print(sorted(skipBigramExample[text][i[0]][max_d].items(),key=lambda x: -x[1])[0])
#         print('\n')
# Out:
# focus-n 	 18
#
#
# ability-n 	 18
#
#
# absence-n 	 18
#
#
# account-n 	 18
#
#
# achievement-n 	 18
#
#
# act-n 	 18
#
#
# action-n 	 18
#
#
# activity-n 	 18
#
#
# addition-n 	 18
#
#
# adoption-n 	 18
#
#
# adult-n 	 18
#
#
# advance-n 	 18
#
#
# advantage-n 	 18
#
#
# advice-n 	 18
#
#
# age-n 	 18
#
#
# aim-n 	 18
#
#
# alternative-n 	 18
#
#
# amount-n 	 18
#
#
# analogy-n 	 18
#
#
# analysis-n 	 18
#
#
# application-n 	 18
#
#
# approach-n 	 18
#
#
# argument-n 	 18
#
#
# aspect-n 	 18
#
#
# assertion-n 	 18
#
#
# assessment-n 	 18
#
#
# assistance-n 	 18
#
#
# association-n 	 18
#
#
# assumption-n 	 18
# a-priori-adj (-1, 22) ('a-priori-adj assumption-n', 22)
#
#
# attempt-n 	 18
#
#
# attention-n 	 18
#
#
# attitude-n 	 18
#
#
# author-n 	 18
#
#
# awareness-n 	 18
#
#
# balance-n 	 18
#
#
# basis-n 	 18
#
#
# behaviour-n 	 18
#
#
# behavior-n 	 18
#
#
# being-n 	 18
#
#
# belief-n 	 18
#
#
# benefit-n 	 18
#
#
# bias-n 	 18
#
#
# birth-n 	 18
#
#
# capacity-n 	 18
#
#
# case-n 	 18
#
#
# category-n 	 18
#
#
# cause-n 	 18
#
#
# centre-n 	 18
#
#
# challenge-n 	 18
#
#
# change-n 	 18
#
#
# character-n 	 18
#
#
# characteristic-n 	 18
#
#
# choice-n 	 18
#
#
# circumstance-n 	 18
#
#
# class-n 	 18
#
#
# classification-n 	 18
#
#
# code-n 	 18
#
#
# colleague-n 	 18
#
#
# combination-n 	 18
#
#
# commitment-n 	 18
#
#
# committee-n 	 18
#
#
# communication-n 	 18
#
#
# community-n 	 18
#
#
# comparison-n 	 18
#
#
# complexity-n 	 18
#
#
# compromise-n 	 18
#
#
# concentration-n 	 18
#
#
# concept-n 	 18
#
#
# conception-n 	 18
#
#
# concern-n 	 18
#
#
# conclusion-n 	 18
#
#
# condition-n 	 18
#
#
# conduct-n 	 18
#
#
# conflict-n 	 18
#
#
# consensus-n 	 18
#
#
# consequence-n 	 18
#
#
# consideration-n 	 18
#
#
# constraint-n 	 18
#
#
# construction-n 	 18
#
#
# content-n 	 18
#
#
# contradiction-n 	 18
#
#
# contrast-n 	 18
#
#
# contribution-n 	 18
#
#
# control-n 	 18
#
#
# convention-n 	 18
#
#
# correlation-n 	 18
#
#
# country-n 	 18
#
#
# creation-n 	 18
#
#
# crisis-n 	 18
#
#
# criterion-n 	 18
#
#
# criticism-n 	 18
#
#
# culture-n 	 18
#
#
# damage-n 	 18
#
#
# data-n 	 18
#
#
# debate-n 	 18
#
#
# decision-n 	 18
#
#
# decline-n 	 18
#
#
# defence-n 	 18
#
#
# defense-n 	 18
#
#
# definition-n 	 18
#
#
# degree-n 	 18
#
#
# demand-n 	 18
#
#
# description-n 	 18
#
#
# destruction-n 	 18
#
#
# determination-n 	 18
#
#
# development-n 	 18
#
#
# difference-n 	 18
#
#
# difficulty-n 	 18
#
#
# dilemma-n 	 18
#
#
# dimension-n 	 18
#
#
# disadvantage-n 	 18
#
#
# discovery-n 	 18
#
#
# discrimination-n 	 18
#
#
# discussion-n 	 18
#
#
# distinction-n 	 18
#
#
# diversity-n 	 18
#
#
# division-n 	 18
#
#
# doctrine-n 	 18
#
#
# effect-n 	 18
#
#
# effectiveness-n 	 18
#
#
# element-n 	 18
#
#
# emphasis-n 	 18
#
#
# environment-n 	 18
#
#
# error-n 	 18
# a-posteriori-adj (-1, 71) ('a-posteriori-adj error-n', 71)
#
#
# essence-n 	 18
#
#
# establishment-n 	 18
#
#
# evaluation-n 	 18
#
#
# event-n 	 18
#
#
# evidence-n 	 18
#
#
# evolution-n 	 18
#
#
# examination-n 	 18
#
#
# example-n 	 18
#
#
# exception-n 	 18
#
#
# exclusion-n 	 18
#
#
# existence-n 	 18
#
#
# expansion-n 	 18
#
#
# experience-n 	 18
#
#
# experiment-n 	 18
#
#
# explanation-n 	 18
#
#
# exposure-n 	 18
#
#
# extent-n 	 18
#
#
# extreme-n 	 18
#
#
# fact-n 	 18
#
#
# factor-n 	 18
#
#
# failure-n 	 18
#
#
# feature-n 	 18
#
#
# female-n 	 18
#
#
# figure-n 	 18
#
#
# finding-n 	 18
#
#
# force-n 	 18
#
#
# form-n 	 18
#
#
# formation-n 	 18
#
#
# function-n 	 18
#
#
# future-n 	 18
#
#
# gain-n 	 18
#
#
# group-n 	 18
#
#
# growth-n 	 18
#
#
# guidance-n 	 18
#
#
# guideline-n 	 18
#
#
# hypothesis-n 	 18
#
#
# idea-n 	 18
#
#
# identity-n 	 18
#
#
# impact-n 	 18
#
#
# implication-n 	 18
#
#
# importance-n 	 18
#
#
# improvement-n 	 18
#
#
# increase-n 	 18
#
#
# indication-n 	 18
#
#
# individual-n 	 18
#
#
# influence-n 	 18
#
#
# information-n 	 18
# a-priori-adj (-1, 111) ('a-priori-adj information-n', 111)
#
#
# insight-n 	 18
#
#
# instance-n 	 18
#
#
# institution-n 	 18
#
#
# integration-n 	 18
#
#
# interaction-n 	 18
#
#
# interest-n 	 18
#
#
# interpretation-n 	 18
#
#
# intervention-n 	 18
#
#
# introduction-n 	 18
#
#
# investigation-n 	 18
#
#
# isolation-n 	 18
#
#
# issue-n 	 18
#
#
# kind-n 	 18
#
#
# knowledge-n 	 18
# a-priori-adj (-1, 330) ('a-priori-adj knowledge-n', 330)
#
#
# lack-n 	 18
#
#
# learning-n 	 18
#
#
# level-n 	 18
#
#
# likelihood-n 	 18
#
#
# limit-n 	 18
#
#
# limitation-n 	 18
#
#
# link-n 	 18
#
#
# list-n 	 18
#
#
# literature-n 	 18
#
#
# logic-n 	 18
# abadi-rogaway-adj (-1, 30) ('abadi-rogaway-adj logic-n', 30)
#
#
# loss-n 	 18
#
#
# maintenance-n 	 18
#
#
# majority-n 	 18
#
#
# male-n 	 18
#
#
# manipulation-n 	 18
#
#
# mankind-n 	 18
#
#
# material-n 	 18
#
#
# means-n 	 18
#
#
# measure-n 	 18
#
#
# medium-n 	 18
#
#
# member-n 	 18
#
#
# method-n 	 18
# ab-initio-adj (-1, 20) ('ab-initio-adj method-n', 20)
#
#
# minority-n 	 18
#
#
# mode-n 	 18
#
#
# model-n 	 18
# a-priori-adj (-1, 23) ('a-priori-adj model-n', 23)
#
#
# motivation-n 	 18
#
#
# movement-n 	 18
#
#
# need-n 	 18
#
#
# network-n 	 18
#
#
# norm-n 	 18
#
#
# notion-n 	 18
#
#
# number-n 	 18
#
#
# observation-n 	 18
#
#
# observer-n 	 18
#
#
# occurrence-n 	 18
#
#
# operation-n 	 18
#
#
# opportunity-n 	 18
#
#
# option-n 	 18
# abandonment-n (-1, 21) ('abandonment-n option-n', 21)
#
#
# organisation-n 	 18
#
#
# organization-n 	 18
#
#
# outcome-n 	 18
#
#
# output-n 	 18
# generate-v (-2, 43) ('generate-v an-det output-n', 43)
#
#
# paper-n 	 18
#
#
# parallel-n 	 18
#
#
# parent-n 	 18
#
#
# part-n 	 18
#
#
# participant-n 	 18
#
#
# past-n 	 18
#
#
# pattern-n 	 18
#
#
# percentage-n 	 18
#
#
# perception-n 	 18
#
#
# period-n 	 18
#
#
# person-n 	 18
#
#
# personality-n 	 18
#
#
# perspective-n 	 18
#
#
# phenomenon-n 	 18
#
#
# point-n 	 18
#
#
# policy-n 	 18
#
#
# population-n 	 18
#
#
# position-n 	 18
#
#
# possibility-n 	 18
#
#
# potential-n 	 18
#
#
# practice-n 	 18
#
#
# presence-n 	 18
#
#
# pressure-n 	 18
#
#
# problem-n 	 18
#
#
# procedure-n 	 18
#
#
# process-n 	 18
#
#
# production-n 	 18
#
#
# programme-n 	 18
#
#
# program-n 	 18
#
#
# progress-n 	 18
#
#
# property-n 	 18
#
#
# proportion-n 	 18
#
#
# proposition-n 	 18
#
#
# protection-n 	 18
#
#
# provision-n 	 18
#
#
# publication-n 	 18
#
#
# purpose-n 	 18
#
#
# quality-n 	 18
#
#
# question-n 	 18
#
#
# range-n 	 18
#
#
# rate-n 	 18
# abandonment-n (-1, 31) ('abandonment-n rate-n', 31)
#
#
# reader-n 	 18
#
#
# reality-n 	 18
#
#
# reason-n 	 18
#
#
# reasoning-n 	 18
#
#
# recognition-n 	 18
#
#
# reduction-n 	 18
#
#
# reference-n 	 18
#
#
# relation-n 	 18
#
#
# relationship-n 	 18
#
#
# relevance-n 	 18
#
#
# report-n 	 18
#
#
# representative-n 	 18
#
#
# reproduction-n 	 18
#
#
# requirement-n 	 18
#
#
# research-n 	 18
#
#
# resistance-n 	 18
#
#
# resolution-n 	 18
#
#
# resource-n 	 18
#
#
# respect-n 	 18
#
#
# restriction-n 	 18
#
#
# result-n 	 18
#
#
# review-n 	 18
#
#
# rise-n 	 18
#
#
# risk-n 	 18
#
#
# role-n 	 18
#
#
# rule-n 	 18
#
#
# sample-n 	 18
#
#
# scale-n 	 18
#
#
# scheme-n 	 18
#
#
# scope-n 	 18
#
#
# search-n 	 18
#
#
# section-n 	 18
#
#
# selection-n 	 18
#
#
# sense-n 	 18
#
#
# separation-n 	 18
#
#
# series-n 	 18
#
#
# service-n 	 18
#
#
# set-n 	 18
#
#
# sex-n 	 18
#
#
# shift-n 	 18
#
#
# significance-n 	 18
#
#
# similarity-n 	 18
#
#
# situation-n 	 18
#
#
# skill-n 	 18
#
#
# society-n 	 18
#
#
# solution-n 	 18
#
#
# source-n 	 18
#
#
# space-n 	 18
#
#
# spread-n 	 18
#
#
# standard-n 	 18
#
#
# statistics-n 	 18
#
#
# stimulus-n 	 18
#
#
# strategy-n 	 18
#
#
# stress-n 	 18
#
#
# structure-n 	 18
#
#
# subject-n 	 18
#
#
# success-n 	 18
#
#
# summary-n 	 18
#
#
# support-n 	 18
#
#
# survey-n 	 18
#
#
# system-n 	 18
#
#
# target-n 	 18
#
#
# task-n 	 18
#
#
# team-n 	 18
#
#
# technique-n 	 18
#
#
# tendency-n 	 18
#
#
# tension-n 	 18
#
#
# term-n 	 18
#
#
# theme-n 	 18
#
#
# theory-n 	 18
#
#
# tolerance-n 	 18
#
#
# topic-n 	 18
#
#
# tradition-n 	 18
#
#
# transition-n 	 18
#
#
# trend-n 	 18
#
#
# type-n 	 18
#
#
# uncertainty-n 	 18
#
#
# understanding-n 	 18
#
#
# unit-n 	 18
#
#
# use-n 	 18
#
#
# validity-n 	 18
#
#
# value-n 	 18
#
#
# variation-n 	 18
#
#
# variety-n 	 18
#
#
# version-n 	 18
#
#
# view-n 	 18
#
#
# viewpoint-n 	 18
#
#
# volume-n 	 18
#
#
# whole-n 	 18
#
#
# work-n 	 18
#
#
# world-n 	 18
#
#
# accept-v 	 18
#
#
# account-v 	 18
#
#
# achieve-v 	 18
#
#
# acquire-v 	 18
#
#
# act-v 	 18
#
#
# adapt-v 	 18
#
#
# adopt-v 	 18
#
#
# advance-v 	 18
#
#
# advocate-v 	 18
#
#
# affect-v 	 18
#
#
# aid-v 	 18
#
#
# aim-v 	 18
#
#
# allocate-v 	 18
#
#
# allow-v 	 18
#
#
# alter-v 	 18
#
#
# analyse-v 	 18
# generate-v (-2, 61) ('generate-v and-c analyse-v', 61)
#
#
# analyze-v 	 18
# generate-v (-2, 124) ('generate-v and-c analyze-v', 124)
#
#
# appear-v 	 18
#
#
# apply-v 	 18
# generate-v (-2, 39) ('generate-v and-c apply-v', 39)
#
#
# argue-v 	 18
#
#
# arise-v 	 18
#
#
# assert-v 	 18
#
#
# assess-v 	 18
#
#
# assign-v 	 18
#
#
# associate-v 	 18
#
#
# assist-v 	 18
#
#
# assume-v 	 18
#
#
# attain-v 	 18
#
#
# attempt-v 	 18
#
#
# attend-v 	 18
#
#
# attribute-v 	 18
#
#
# avoid-v 	 18
#
#
# base-v 	 18
#
#
# be-v 	 18
# a-synuclein-n (-1, 29) ('a-synuclein-n be-v', 29)
# generate-v (-2, 24) ('generate-v and-c be-v', 24)
#
#
# become-v 	 18
#
#
# benefit-v 	 18
#
#
# can-v 	 18
#
#
# cause-v 	 18
#
#
# characterise-v 	 18
#
#
# characterize-v 	 18
# generate-v (-2, 40) ('generate-v and-c characterize-v', 40)
#
#
# choose-v 	 18
#
#
# cite-v 	 18
#
#
# claim-v 	 18
#
#
# clarify-v 	 18
#
#
# classify-v 	 18
#
#
# coincide-v 	 18
#
#
# combine-v 	 18
#
#
# compare-v 	 18
#
#
# compete-v 	 18
#
#
# comprise-v 	 18
#
#
# concentrate-v 	 18
#
#
# concern-v 	 18
#
#
# conclude-v 	 18
#
#
# conduct-v 	 18
#
#
# confine-v 	 18
#
#
# conform-v 	 18
#
#
# connect-v 	 18
#
#
# consider-v 	 18
#
#
# consist-v 	 18
#
#
# constitute-v 	 18
#
#
# construct-v 	 18
#
#
# contain-v 	 18
#
#
# contrast-v 	 18
#
#
# contribute-v 	 18
#
#
# control-v 	 18
#
#
# convert-v 	 18
#
#
# correspond-v 	 18
#
#
# create-v 	 18
#
#
# damage-v 	 18
#
#
# deal-v 	 18
#
#
# decline-v 	 18
#
#
# define-v 	 18
#
#
# demonstrate-v 	 18
#
#
# depend-v 	 18
#
#
# derive-v 	 18
#
#
# describe-v 	 18
#
#
# design-v 	 18
#
#
# destroy-v 	 18
#
#
# determine-v 	 18
#
#
# develop-v 	 18
#
#
# differ-v 	 18
#
#
# differentiate-v 	 18
#
#
# diminish-v 	 18
#
#
# direct-v 	 18
#
#
# discuss-v 	 18
#
#
# display-v 	 18
#
#
# distinguish-v 	 18
#
#
# divide-v 	 18
#
#
# dominate-v 	 18
#
#
# effect-v 	 18
#
#
# eliminate-v 	 18
#
#
# emerge-v 	 18
#
#
# emphasize-v 	 18
#
#
# employ-v 	 18
#
#
# enable-v 	 18
#
#
# encounter-v 	 18
#
#
# encourage-v 	 18
#
#
# enhance-v 	 18
#
#
# ensure-v 	 18
#
#
# establish-v 	 18
#
#
# evaluate-v 	 18
#
#
# evolve-v 	 18
#
#
# examine-v 	 18
#
#
# exceed-v 	 18
#
#
# exclude-v 	 18
#
#
# exemplify-v 	 18
#
#
# exist-v 	 18
#
#
# expand-v 	 18
#
#
# experience-v 	 18
#
#
# explain-v 	 18
#
#
# expose-v 	 18
#
#
# express-v 	 18
#
#
# extend-v 	 18
#
#
# facilitate-v 	 18
#
#
# fail-v 	 18
#
#
# favour-v 	 18
#
#
# favor-v 	 18
#
#
# finance-v 	 18
#
#
# focus-v 	 18
#
#
# follow-v 	 18
#
#
# form-v 	 18
#
#
# formulate-v 	 18
#
#
# function-v 	 18
#
#
# gain-v 	 18
#
#
# generate-v 	 18
# optimal-adj (2, 143) ('generate-v an-det optimal-adj', 143)
# analyze-v (2, 124) ('generate-v and-c analyze-v', 124)
# s-n (2, 91) ('generate-v an-det s-n', 91)
# analyse-v (2, 61) ('generate-v and-c analyse-v', 61)
# output-n (2, 43) ('generate-v an-det output-n', 43)
# characterize-v (2, 40) ('generate-v and-c characterize-v', 40)
# optimize-v (2, 39) ('generate-v an-det optimize-v', 39)
# apply-v (2, 39) ('generate-v and-c apply-v', 39)
# animate-v (2, 24) ('generate-v and-c animate-v', 24)
# be-v (2, 24) ('generate-v and-c be-v', 24)
#
#
# govern-v 	 18
#
#
# highlight-v 	 18
#
#
# identify-v 	 18
#
#
# illustrate-v 	 18
#
#
# imply-v 	 18
#
#
# impose-v 	 18
#
#
# improve-v 	 18
#
#
# include-v 	 18
#
#
# incorporate-v 	 18
#
#
# increase-v 	 18
#
#
# indicate-v 	 18
#
#
# induce-v 	 18
#
#
# influence-v 	 18
#
#
# initiate-v 	 18
#
#
# integrate-v 	 18
#
#
# interpret-v 	 18
#
#
# introduce-v 	 18
#
#
# investigate-v 	 18
#
#
# involve-v 	 18
#
#
# isolate-v 	 18
#
#
# label-v 	 18
#
#
# lack-v 	 18
#
#
# lead-v 	 18
#
#
# limit-v 	 18
#
#
# link-v 	 18
#
#
# locate-v 	 18
#
#
# maintain-v 	 18
#
#
# may-v 	 18
#
#
# measure-v 	 18
#
#
# neglect-v 	 18
#
#
# note-v 	 18
#
#
# obtain-v 	 18
#
#
# occur-v 	 18
#
#
# operate-v 	 18
#
#
# outline-v 	 18
#
#
# overcome-v 	 18
#
#
# participate-v 	 18
#
#
# perceive-v 	 18
#
#
# perform-v 	 18
#
#
# permit-v 	 18
#
#
# pose-v 	 18
#
#
# possess-v 	 18
#
#
# precede-v 	 18
#
#
# predict-v 	 18
#
#
# present-v 	 18
#
#
# preserve-v 	 18
#
#
# prevent-v 	 18
#
#
# produce-v 	 18
#
#
# promote-v 	 18
#
#
# propose-v 	 18
#
#
# prove-v 	 18
#
#
# provide-v 	 18
#
#
# publish-v 	 18
#
#
# pursue-v 	 18
#
#
# quote-v 	 18
#
#
# receive-v 	 18
#
#
# record-v 	 18
#
#
# reduce-v 	 18
#
#
# refer-v 	 18
#
#
# reflect-v 	 18
#
#
# regard-v 	 18
#
#
# regulate-v 	 18
#
#
# reinforce-v 	 18
#
#
# reject-v 	 18
#
#
# relate-v 	 18
#
#
# rely-v 	 18
#
#
# remain-v 	 18
#
#
# remove-v 	 18
#
#
# render-v 	 18
#
#
# replace-v 	 18
#
#
# report-v 	 18
#
#
# represent-v 	 18
#
#
# reproduce-v 	 18
#
#
# require-v 	 18
#
#
# resolve-v 	 18
#
#
# respond-v 	 18
#
#
# restrict-v 	 18
#
#
# result-v 	 18
#
#
# retain-v 	 18
#
#
# reveal-v 	 18
#
#
# seek-v 	 18
#
#
# select-v 	 18
#
#
# separate-v 	 18
#
#
# should-v 	 18
#
#
# show-v 	 18
#
#
# solve-v 	 18
#
#
# specify-v 	 18
#
#
# state-v 	 18
#
#
# stimulate-v 	 18
#
#
# strengthen-v 	 18
#
#
# stress-v 	 18
#
#
# study-v 	 18
#
#
# submit-v 	 18
#
#
# suffer-v 	 18
#
#
# suggest-v 	 18
#
#
# summarise-v 	 18
#
#
# summarize-v 	 18
#
#
# supply-v 	 18
#
#
# support-v 	 18
#
#
# sustain-v 	 18
#
#
# tackle-v 	 18
#
#
# tend-v 	 18
#
#
# term-v 	 18
#
#
# transform-v 	 18
#
#
# treat-v 	 18
#
#
# undermine-v 	 18
#
#
# undertake-v 	 18
#
#
# use-v 	 18
#
#
# vary-v 	 18
#
#
# view-v 	 18
#
#
# write-v 	 18
#
#
# yield-v 	 18
#
#
# absolute-adj 	 18
#
#
# abstract-adj 	 18
#
#
# acceptable-adj 	 18
#
#
# accessible-adj 	 18
#
#
# active-adj 	 18
#
#
# actual-adj 	 18
#
#
# acute-adj 	 18
#
#
# additional-adj 	 18
#
#
# adequate-adj 	 18
#
#
# alternative-adj 	 18
#
#
# apparent-adj 	 18
#
#
# applicable-adj 	 18
#
#
# appropriate-adj 	 18
#
#
# arbitrary-adj 	 18
#
#
# available-adj 	 18
#
#
# average-adj 	 18
#
#
# basic-adj 	 18
#
#
# central-adj 	 18
#
#
# certain-adj 	 18
#
#
# clear-adj 	 18
#
#
# common-adj 	 18
#
#
# competitive-adj 	 18
#
#
# complete-adj 	 18
#
#
# complex-adj 	 18
#
#
# comprehensive-adj 	 18
#
#
# considerable-adj 	 18
#
#
# consistent-adj 	 18
#
#
# conventional-adj 	 18
#
#
# correct-adj 	 18
#
#
# critical-adj 	 18
#
#
# crucial-adj 	 18
#
#
# dependent-adj 	 18
#
#
# detailed-adj 	 18
#
#
# different-adj 	 18
#
#
# difficult-adj 	 18
#
#
# distinct-adj 	 18
#
#
# dominant-adj 	 18
#
#
# early-adj 	 18
#
#
# effective-adj 	 18
#
#
# equal-adj 	 18
#
#
# equivalent-adj 	 18
#
#
# essential-adj 	 18
#
#
# evident-adj 	 18
#
#
# excessive-adj 	 18
#
#
# experimental-adj 	 18
#
#
# explicit-adj 	 18
#
#
# extensive-adj 	 18
#
#
# extreme-adj 	 18
#
#
# far-adj 	 18
#
#
# favourable-adj 	 18
#
#
# favorable-adj 	 18
#
#
# final-adj 	 18
#
#
# fixed-adj 	 18
#
#
# following-adj 	 18
#
#
# formal-adj 	 18
#
#
# frequent-adj 	 18
#
#
# fundamental-adj 	 18
#
#
# future-adj 	 18
#
#
# general-adj 	 18
#
#
# great-adj 	 18
#
#
# high-adj 	 18
#
#
# human-adj 	 18
#
#
# ideal-adj 	 18
#
#
# identical-adj 	 18
#
#
# immediate-adj 	 18
#
#
# important-adj 	 18
#
#
# inadequate-adj 	 18
#
#
# incomplete-adj 	 18
#
#
# independent-adj 	 18
#
#
# indirect-adj 	 18
#
#
# individual-adj 	 18
#
#
# inferior-adj 	 18
#
#
# influential-adj 	 18
#
#
# inherent-adj 	 18
#
#
# initial-adj 	 18
#
#
# interesting-adj 	 18
#
#
# internal-adj 	 18
#
#
# large-adj 	 18
#
#
# late-adj 	 18
#
#
# leading-adj 	 18
#
#
# likely-adj 	 18
#
#
# limited-adj 	 18
#
#
# local-adj 	 18
#
#
# logical-adj 	 18
#
#
# main-adj 	 18
#
#
# major-adj 	 18
#
#
# male-adj 	 18
#
#
# maximum-adj 	 18
#
#
# mental-adj 	 18
#
#
# minimal-adj 	 18
#
#
# minor-adj 	 18
#
#
# misleading-adj 	 18
#
#
# modern-adj 	 18
#
#
# mutual-adj 	 18
#
#
# natural-adj 	 18
#
#
# necessary-adj 	 18
#
#
# negative-adj 	 18
#
#
# new-adj 	 18
#
#
# normal-adj 	 18
#
#
# obvious-adj 	 18
#
#
# original-adj 	 18
#
#
# other-adj 	 18
#
#
# overall-adj 	 18
#
#
# parallel-adj 	 18
#
#
# partial-adj 	 18
#
#
# particular-adj 	 18
#
#
# passive-adj 	 18
#
#
# past-adj 	 18
#
#
# permanent-adj 	 18
#
#
# physical-adj 	 18
#
#
# positive-adj 	 18
#
#
# possible-adj 	 18
#
#
# potential-adj 	 18
#
#
# practical-adj 	 18
#
#
# present-adj 	 18
#
#
# previous-adj 	 18
#
#
# primary-adj 	 18
#
#
# prime-adj 	 18
#
#
# principal-adj 	 18
#
#
# productive-adj 	 18
#
#
# profound-adj 	 18
#
#
# progressive-adj 	 18
#
#
# prominent-adj 	 18
#
#
# psychological-adj 	 18
#
#
# radical-adj 	 18
#
#
# random-adj 	 18
#
#
# rapid-adj 	 18
#
#
# rational-adj 	 18
#
#
# real-adj 	 18
# realistic-adj 	 18
#
#
# recent-adj 	 18
#
#
# related-adj 	 18
#
#
# relative-adj 	 18
#
#
# relevant-adj 	 18
#
#
# representative-adj 	 18
#
#
# responsible-adj 	 18
#
#
# restricted-adj 	 18
#
#
# scientific-adj 	 18
#
#
# secondary-adj 	 18
#
#
# selective-adj 	 18
#
#
# separate-adj 	 18
#
#
# severe-adj 	 18
#
#
# sexual-adj 	 18
#
#
# significant-adj 	 18
#
#
# similar-adj 	 18
#
#
# simple-adj 	 18
#
#
# single-adj 	 18
#
#
# so-called-adj 	 18
#
#
# social-adj 	 18
#
#
# special-adj 	 18
#
#
# specific-adj 	 18
#
#
# stable-adj 	 18
#
#
# standard-adj 	 18
#
#
# strict-adj 	 18
#
#
# subsequent-adj 	 18
#
#
# substantial-adj 	 18
#
#
# successful-adj 	 18
#
#
# successive-adj 	 18
#
#
# sufficient-adj 	 18
#
#
# suitable-adj 	 18
#
#
# surprising-adj 	 18
#
#
# symbolic-adj 	 18
#
#
# systematic-adj 	 18
#
#
# theoretical-adj 	 18
#
#
# total-adj 	 18
#
#
# traditional-adj 	 18
#
#
# true-adj 	 18
#
#
# typical-adj 	 18
#
#
# unique-adj 	 18
#
#
# unlike-adj 	 18
#
#
# unlikely-adj 	 18
#
#
# unsuccessful-adj 	 18
#
#
# useful-adj 	 18
#
#
# valid-adj 	 18
#
#
# valuable-adj 	 18
#
#
# varied-adj 	 18
#
#
# various-adj 	 18
#
#
# visual-adj 	 18
#
#
# vital-adj 	 18
#
#
# wide-adj 	 18
#
#
# widespread-adj 	 18
#
#
# above-adv 	 18
#
#
# accordingly-adv 	 18
#
#
# accurately-adv 	 18
#
#
# adequately-adv 	 18
#
#
# also-adv 	 18
#
#
# approximately-adv 	 18
#
#
# at best-adv 	 18
#
#
# basically-adv 	 18
#
#
# clearly-adv 	 18
#
#
# closely-adv 	 18
#
#
# commonly-adv 	 18
#
#
# consequently-adv 	 18
#
#
# considerably-adv 	 18
#
#
# conversely-adv 	 18
#
#
# correctly-adv 	 18
#
#
# directly-adv 	 18
#
#
# effectively-adv 	 18
#
#
# e.g.-adv 	 18
#
#
# either-adv 	 18
#
#
# equally-adv 	 18
#
#
# especially-adv 	 18
#
#
# essentially-adv 	 18
#
#
# explicitly-adv 	 18
#
#
# extremely-adv 	 18
#
#
# fairly-adv 	 18
#
#
# far-adv 	 18
#
#
# for example-adv 	 18
#
#
# for instance-adv 	 18
#
#
# frequently-adv 	 18
#
#
# fully-adv 	 18
#
#
# further-adv 	 18
#
#
# generally-adv 	 18
#
#
# greatly-adv 	 18
#
#
# hence-adv 	 18
#
#
# highly-adv 	 18
#
#
# however-adv 	 18
#
#
# increasingly-adv 	 18
#
#
# indeed-adv 	 18
#
#
# independently-adv 	 18
#
#
# indirectly-adv 	 18
#
#
# inevitably-adv 	 18
#
#
# initially-adv 	 18
#
#
# in general-adv 	 18
#
#
# in particular-adv 	 18
#
#
# largely-adv 	 18
#
#
# less-adv 	 18
#
#
# mainly-adv 	 18
#
#
# more-adv 	 18
#
#
# moreover-adv 	 18
#
#
# most-adv 	 18
#
#
# namely-adv 	 18
#
#
# necessarily-adv 	 18
#
#
# normally-adv 	 18
#
#
# notably-adv 	 18
#
#
# often-adv 	 18
#
#
# only-adv 	 18
#
#
# originally-adv 	 18
#
#
# over-adv 	 18
#
#
# partially-adv 	 18
#
#
# particularly-adv 	 18
#
#
# potentially-adv 	 18
#
#
# previously-adv 	 18
#
#
# primarily-adv 	 18
#
#
# purely-adv 	 18
#
#
# readily-adv 	 18
#
#
# recently-adv 	 18
#
#
# relatively-adv 	 18
#
#
# secondly-adv 	 18
#
#
# significantly-adv 	 18
#
#
# similarly-adv 	 18
#
#
# simply-adv 	 18
#
#
# socially-adv 	 18
#
#
# solely somewhat-adv 	 18
#
#
# specifically-adv 	 18
#
#
# strongly-adv 	 18
#
#
# subsequently-adv 	 18
#
#
# successfully-adv 	 18
#
#
# thereby-adv 	 18
#
#
# therefore-adv 	 18
#
#
# thus-adv 	 18
#
#
# traditionally-adv 	 18
#
#
# typically-adv 	 18
#
#
# ultimately-adv 	 18
#
#
# virtually-adv 	 18
#
#
# wholly-adv 	 18
#
#
# widely-adv 	 18
