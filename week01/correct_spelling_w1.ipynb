# %%
import re
from collections import Counter

def words(text): return re.findall('[a-z]+', text.lower())

def words_and_bigrams(text):
  all_words = words(text)
  bigrams = [ ' '.join(all_words[i:i+2]) for i in range(len(all_words)-1) ]
  return all_words + bigrams

NWORDS = Counter(words_and_bigrams(open('big.txt').read()))

alphabet = 'abcdefghijklmnopqrstuvwxyz'

def edits1(word):
   splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
   deletes    = [a + b[1:] for a, b in splits if b]
   transposes = [a + b[1] + b[0] + b[2:] for a, b in splits if len(b)>1]
   replaces   = [a + c + b[1:] for a, b in splits for c in alphabet if b]
   inserts    = [a + c + b     for a, b in splits for c in alphabet+' ' ]
   return set(deletes + transposes + replaces + inserts)

def known_edits2(word):
    return set(e2 for e1 in edits1(word) for e2 in edits1(e1) if e2 in NWORDS)

def known(words): return set(w for w in words if w in NWORDS)

# list all possible fusion error candidate
def fusions_edit(word):
   word        = word.replace(' ', '')
   splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
   fusions    = [(a+' '+b) for a, b in splits if a in NWORDS and b in NWORDS]
   if word in NWORDS:
      fusions += [word]
   return fusions

def correct(word):
    candidates = known([word]) or known(edits1(word)) or known_edits2(word) or [word]
    fusions = fusions_edit(word)
    # correct with fusion error first
    if fusions:
        return max(fusions, key=lambda w: NWORDS[w]) #key=lambda p: p.totalScore)
    # correct with edit candidate if no fusion candidate found
    return max(candidates, key=lambda w: NWORDS[w])

def get_all_candidates(word):
    return known([word]) | known(edits1(word)) | known_edits2(word) or [word]

print(correct('gardon'))
# Out:
# garden

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import requests
API_URL = "http://linggle.com/query/"

class Linggle:
    def __getitem__(self, query):
        return self.search(query)

    def search(self, query):
        req = requests.get('http://linggle.com/query/' + query)
        results = req.json()
        results = [item['phrase'] for item in results]
        return results

SE = Linggle()

# %%
import Levenshtein
from collections import defaultdict

# ['w1','w2','w3','w4'] : gram_len = 4, 分組公式：len - (num - 1)
def get_groups(word_list, window_size):
    groups = [word_list[i: i + window_size] for i in range(len(word_list) - (window_size - 1))]
#     print(groups)
    return groups

def LCS(X, Y): # longest common subsequence
    m = len(X)
    n = len(Y)
    # An (m+1) times (n+1) matrix
    C = [[0] * (n + 1) for _ in range(m + 1)]
    for i in range(1, m+1):
        for j in range(1, n+1):
            if X[i-1] == Y[j-1]: 
                C[i][j] = C[i-1][j-1] + 1
            else:
                C[i][j] = max(C[i][j-1], C[i-1][j])
    return C

WINDOW_SIZE = 3
def get_correct(query):
    words = query.split()
    groups = get_groups(words, WINDOW_SIZE)
    
    for i, group in enumerate(groups):
        diff_words = [(group[i], i) for i in range(WINDOW_SIZE) if not group[i] == correct(group[i])] 
        
        # 可能需要補充句子全正確但是用錯單字的
        if not diff_words: continue
            
        # 篩選出含有 wrong word 機率的 gram
        for wrong_word, index in diff_words:
            # mask sentence
            possible_patterns = SE[' '.join(group[0:index] + ['_'] + group[index+1:])] 
            
            # get all possible combination
            for candidate in list(get_all_candidates(wrong_word)):
                possible_patterns += SE[' '.join(group[0:index] + [candidate] + group[index+1:])]
            
            if possible_patterns: # 應該要有 patterns
                dict_similarity = defaultdict(int)
                
                for pattern in possible_patterns:
                    dict_similarity[pattern[index]] = Levenshtein.distance(pattern[index], wrong_word)

                words[i+index] = min(dict_similarity, key=lambda word: dict_similarity[word])
                return ' '.join(words)
            else:
                print('???')
            
if __name__ == "__main__":
#     with open('test.txt', 'r') as input:
    with open('lab2.test.1.txt', 'r') as input:
        score = 0
        for line in input:
            [raw, answer] = line.strip().split('\t')
            
            correction = get_correct(raw)
            
            score += 1 if correction == answer else -1
            
            if correction == answer:
                print('Right: {}'.format(correction))
            else:
                print('Wrong: {} / {}'.format(correction, answer))
#                 print(correction)
#                 print(line)
        print(score)
# Out:
# Wrong: I felt very strang / I felt very strange
# Wrong: None / at break time
# Wrong: when the brick was finished / when the break was finished
# Wrong: in the center when it was snowing / in the winter when it was snowing
# Wrong: I thought it was a gost / I thought it was a ghost
# Wrong: None / everything except the houses
# Wrong: when I first steped / when I first stepped
# Wrong: and saw streaks colow people / and saw strange colow people
# Wrong: and saw streaks colow people / and saw streagh coloured people
# Wrong: I was on an exclation / I was on an escalator
# ???
# Right: I noticed that I was on this thing
# Wrong: through the lance / through the fence
# Wrong: the hunters killed them / the hunters kill them
# Wrong: they kill birds with their narrow / they kill birds with their arrow
# Wrong: make a dupe hole / make a deep hole
# Right: to tidy up his garden
# Wrong: the wind belt the leaves / the wind blew the leaves
# ???
# Wrong: Mr J was very angray / Mr J. was very angry
# Wrong: garden full of leads / garden full of leaves
# Wrong: None / talk to the manager
# Wrong: they throw a hero / they throw a arrow
# Wrong: an action method of hunting / an ancient method of hunting
# Wrong: None / after the deer
# Wrong: the birds fly up / the birds flew up
# Right: making any noise
# Right: bring it straight to the hunters
# Right: this means a man waits
# Wrong: a man weight for the animal / a man waits for the animal
# Right: an arrow in his hand
# Wrong: None / they dig a hole
# Right: a piece of bait
# Wrong: this trip looks like a cave / this trap looks like a cave
# Wrong: None / they make noise
# Wrong: the animals are heard / the animals are scared
# Wrong: the diabetes will run / the rabbits will run
# Right: they throw stones
# Right: they chasing the animals
# Right: three hundred people
# Right: it was colourful
# Wrong: I saw many crowns / I saw many clowns
# Right: could do it easily
# Right: blood was coming out
# Wrong: None / you have wandered away
# Right: you can control with your toes
# Wrong: coating to each other / chatting to each other
# Right: out from the wardrobe
# Right: for controlling temperature
# Right: friendly with your neighbours
# Right: the princess has given birth
# Right: to make arrangements
# Wrong: hit him with a homer / hit him with a hammer
# Wrong: they it see you / they might see you
# Right: transport is different
# Wrong: they have different cover / they have different clothes
# Wrong: a plastic carrier / a plastic sharpener
# Right: the chinese invented paper
# Wrong: a total of lemonade / a bottle of lemonade
# Wrong: None / to hear you
# Wrong: None / on and off
# Right: if you are thirsty
# Wrong: None / a match box
# Wrong: all of a sadden / all of a sudden
# Wrong: went up the cotton / went up the curtain
# Right: with bubbles in it
# Wrong: so I had a barth / so I had a bath
# ???
# Wrong: I made clouds with it / I made clothes with it
# ???
# Wrong: I was heard of it / I was scared of it
# Wrong: None / through the window
# Right: one of my exciting days
# Wrong: found some cases and ate them / found some crumbs and ate them
# Wrong: I was very carful / I was very careful
# Wrong: speaking to a post / speaking to a ghost
# Right: to make people scared
# Right: lit a candle
# Right: a man or a lady
# Right: something bad happened
# Right: thunder and lightning
# Wrong: the inspector the sargent / the inspector, the sergeant
# Wrong: None / a light and a noise
# ???
# Wrong: I would rue a rag / I would rub a rag
# Wrong: such a police car / crush a police car
# ???
# Wrong: Ian walked over / Ian tripped over
# Right: got a tissue from her bag
# Wrong: None / what do you mean
# Wrong: Im writting a letter / I'm writing a letter
# Right: a straight line
# ???
# Wrong: I through it was going to rain / I thought it was going to rain
# Wrong: he just hated to die / he just wanted to die
# Right: bouncing a ball
# Right: ate some fruits
# ???
# ???
# Wrong: None / he doesn't notice
# Right: a bull charging at him
# ???
# ???
# Wrong: None / and ice-cream stall
# Wrong: None / there was a giraffe
# Wrong: None / then a crocodile came
# Wrong: corn is a hard metal / iron is a hard metal
# Wrong: four pen loops / four pen knives
# Wrong: there are four times / there are four chimneys
# Wrong: on the road / on the blackboard
# Wrong: on the gold / on the globe
# Right: in the cupboard
# Right: the light switch
# Wrong: from the thirst / from the thinnest
# Wrong: to the latest / to the fattest
# Right: in a field
# Right: a cherry red dress
# Wrong: None / the beginning of the play
# Right: fried rice and noodles
# Right: carry money with me
# Right: they are believe superstitious
# Wrong: the things I belive / the things I believe
# Right: differences between their knowledge
# Wrong: by logical means / by logical speech
# Wrong: a white color / a white colour
# Wrong: dont make anything beark / don't make anything break
# Wrong: None / to find out
# Right: when a couple
# Wrong: the sustain is being emptyed / the dustbin is being emptyed
# Wrong: the sustain is being emptyed / the dustpin is being emptied
# Wrong: the roof is being prepared / the roof is being repaired
# Right: have to be emptied every day
# Wrong: None / they were cleaned
# Wrong: he believe in the old story / he believes in the old story
# Right: the most famous player
# Wrong: of the centers / of the century
# Wrong: the man had tired to struggle / the man had tried to smuggle
# Right: put more petrol
# Right: he tried to
# Right: heard a strange noise
# Right: he tried to
# Wrong: he hated him / he hit him
# ???
# ???
# Wrong: None / he'd forgotten to
# ???
# ???
# Right: he'd set fire to
# ???
# ???
# Wrong: he'd shouted his wife / he'd shot his wife
# Right: sent them to prison
# Right: crying her eyes out
# Wrong: None / last Monday
# Wrong: None / put on weight
# Wrong: what had happend / what had happened
# ???
# ???
# Right: he'd saved the woman
# Right: become too fat
# Wrong: what had happend / what had happened
# Wrong: in politics today / in holidays today
# Right: photographs of footprints
# ???
# Wrong: None / which cannot be explained
# Wrong: of a wolfe / it's a wolf
# Wrong: they have discoverd / they aren't discovered
# Right: to photograph these things
# Right: an unborn child
# Wrong: the glorious beach / the mysterious beach
# Wrong: None / choosing between
# Right: it represents the
# Right: it is ridiculous that
# Right: is scientifically proved
# Right: there are advertisements for
# Right: it was my imagination
# Right: to ban smoking
# Right: my happiness depends on
# Right: the pleasant smell of
# Wrong: diving the number / dialling the number
# Right: actually I had no
# Wrong: the most stirring part / the most tiring part
# Wrong: games play pocker / gamblers play poker
# Right: the existence of
# Wrong: None / physical sensations
# Right: it is without doubt
# Wrong: let us analyze / let us analyse
# Wrong: None / developing countries
# ???
# Wrong: I personaly believe / I personally believe
# Wrong: as often as I breath / as often as I breathe
# Wrong: None / flowers, perfumes
# Right: to interpret what I've said
# Wrong: my stomache hurt / my stomach hurt
# Wrong: surprised and pleased by / surprised and paralysed by
# Wrong: I belief it was / I believe it was
# Right: when it occurred
# Right: she asked us whether
# Right: an extremely hot day
# Wrong: None / be able to choose
# Right: their opinion about
# Wrong: None / to think what
# Right: to continue with
# Wrong: None / it was quite successful
# ???
# Wrong: I never shout that / I never thought that
# Wrong: and heart that / I'd heard that
# Wrong: None / he obviously reckoned
# Wrong: to pray him / to praise him
# Right: screaming louder than
# Right: to absorb it
# ???
# Wrong: I couldnt stop starring / I couldn't stop staring
# Right: a street cafe
# Right: a movie was shown
# Wrong: company started to work / companies started to work
# Wrong: None / there is
# Right: a tendency to
# Wrong: None / meet in the snack-bar
# Wrong: None / security control
# Right: in contact with
# -38

# %%
print(get_all_candidates('nerrow'))
# Out:
# {'harrow', 'neuro', 'sorrow', 'borrow', 'error', 'terror', 'furrow', 'barrow', 'narrow', 'narrows', 'arrow', 'negro', 'neuron', 'burrow', 'marrow', 'morrow'}
